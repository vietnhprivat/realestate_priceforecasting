# %% [markdown]
# # Bolig data from Dataforsyningen

# %% [markdown]
# ## DAGI

# %% [markdown]
# Pandas indstillinger

# %%
import pandas as pd
# Set pandas options to display all columns and rows
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Set pandas option to display the full content of each column
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Kommune koder i Danmark

# %%
# File path to csv file
path = r"C:\Users\viet-intel\boligpriser\data\input\kommunekoder.csv"

# Load data from csv into datafram
column_names = ['navn', 'kommunekode']
kommune_df = pd.read_csv(path, sep=',', encoding='latin-1', dtype=str, header=None, names=column_names, index_col=False)

# Display the first 5 rows of the dataframe
display(kommune_df.head(3))
display(kommune_df.tail(3))
# Out:
#           navn kommunekode
# 0  Albertslund         165
# 1      Allerød         201
# 2       Assens         420
# 3     Ballerup         151
# 4      Billund         530
#            navn kommunekode
# 93  Vordingborg         390
# 94          Ærø         492
# 95     Aabenraa         580
# 96      Aalborg         851
# 97        Århus         751

# %% [markdown]
# Udvægelse af kommune koder i region hovedstaden

# %%
# List of kommune names in region hovedstaden
region_hovedstad_list = ["Albertslund", "Allerød", "Ballerup", "Bornholms Regionskommune", "Brøndby", 
                "Dragør", "Egedal", "Fredensborg", "Frederiksberg", "Frederikssund", "Furesø", 
                "Gentofte", "Gladsaxe", "Glostrup", "Gribskov", "Halsnæs", "Helsingør", "Herlev", 
                "Hillerød", "Hvidovre", "Høje-Taastrup", "Hørsholm", "Ishøj", "København", "Lyngby-Taarbæk", 
                "Rudersdal", "Rødovre", "Tårnby", "Vallensbæk"]

# Creating new dataframe with only kommune names in region hovedstaden
region_hovedstad_df = kommune_df[kommune_df['navn'].isin(region_hovedstad_list)]

# Creating a list of kommune codes in region hovedstaden
region_hovedstad_kommunekode_list = region_hovedstad_df['kommunekode'].tolist()

# print(region_hovedstad_kommunekode_list)
print(region_hovedstad_kommunekode_list)
# Out:
# ['165', '201', '151', '153', '155', '240', '210', '147', '250', '190', '157', '159', '161', '270', '217', '163', '219', '167', '169', '223', '183', '101', '230', '175', '185', '187']

# %% [markdown]
# Hent alle adresser ud fra kommunekoder

# %%
import requests
import pandas as pd

test_list = ['0165']#, '201', '151', '153', '155', '240', '210', '147', '250', '190', '157', '159', '161', '270', '217', '163', '219', '167', '169', '223', '183', '101', '230', '175', '185', '187']

# Define a function to make an API request to the Danish API for housing data
def housing_data_call(kommunekode):
    # URL to API
    url = f"https://api.dataforsyningen.dk/adresser?kommunekode={kommunekode}&format=csv"

    # Define a session with certificate verification disabled
    session = requests.Session()
    session.verify = False

    try:
        # Make the API request using the session
        response = session.get(url)
        response.raise_for_status()  # Make sure the API call was successful
    except requests.exceptions.RequestException as e:
        print(f"Error while fetching data for kommune {kommunekode}: {e}")
        return None

    # Read the response content as a DataFrame
    load_housing_adresses = pd.read_csv(response.url, low_memory=False, dtype={'col10': 'str'})
    return load_housing_adresses

# Empty list to store the dataframes
data_frame_list = []

# Loop through the kommune codes in the test_list and make an API request for each kommune to fetch the data
for kommune in test_list:
    kommune_data = housing_data_call(kommune)
    if kommune_data is not None:
        data_frame_list.append(kommune_data)

# Concatenate all the dataframes into one dataframe
all_kommune_df = pd.concat(data_frame_list, axis=0, ignore_index=True)

display(all_kommune_df.head())
print("length:", len(all_kommune_df))

# %% [markdown]
# Loading csv to sql

# %%
# define path
path = r"C:\Users\viet-intel\boligpriser\data\input\DAGI.csv"

# load data into dataframe
DAGI_df = pd.read_csv(path)

# print the first 5 rows of the dataframe
display(DAGI_df.head(1))

# print length of dataframe
print("length:", len(DAGI_df))

# print dtypes
print(DAGI_df.dtypes)
# Out:
# C:\Users\viet-intel\AppData\Local\Temp\ipykernel_22808\2309470723.py:5: DtypeWarning: Columns (10,14,71,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   DAGI_df = pd.read_csv(path)
#                                      id  status                 oprettet  \
# 0  ba8c261d-4341-41e2-8fc9-93a483db41c8       1  2016-04-14T08:43:55.757
#
#                     ændret  vejkode      vejnavn adresseringsvejnavn husnr  \
# 0  2016-04-14T08:43:55.757     7043  Skolebakken         Skolebakken    26
#
#   etage  dør supplerendebynavn  postnr postnrnavn  stormodtagerpostnr  \
# 0   NaN  NaN               NaN    8500     Grenaa                 NaN
#
#   stormodtagerpostnrnavn  kommunekode kommunenavn  ejerlavkode  \
# 0                    NaN          707   Norddjurs    2005853.0
#
#                 ejerlavnavn matrikelnr  esrejendomsnr  etrs89koordinat_øst  \
# 0  Bredstrup, Grenaa Jorder        6ah        49804.0            617441.92
#
#    etrs89koordinat_nord  wgs84koordinat_bredde  wgs84koordinat_længde  \
# 0            6253889.63              56.414951              10.903634
#
#   nøjagtighed  kilde tekniskstandard  tekstretning        ddkn_m100  \
# 0           A    5.0              TD        288.38  100m_62538_6174
#
#        ddkn_km1    ddkn_km10 adressepunktændringsdato  \
# 0  1km_6253_617  10km_625_61  2016-04-28T12:06:39.230
#
#                        adgangsadresseid  adgangsadresse_status  \
# 0  490d7c11-11a7-4a8b-ac92-3084e298fb81                      1
#
#    adgangsadresse_oprettet    adgangsadresse_ændret  regionskode  \
# 0  2016-04-14T08:43:55.757  2020-01-16T01:00:00.000         1082
#
#           regionsnavn    jordstykke_ejerlavnavn                 kvhx  \
# 0  Region Midtjylland  Bredstrup, Grenaa Jorder  07077043__26_______
#
#    sognekode sognenavn  politikredskode     politikredsnavn  retskredskode  \
# 0       8231    Grenaa             1461  Østjyllands Politi           1169
#
#       retskredsnavn  opstillingskredskode opstillingskredsnavn    zone  \
# 0  Retten i Randers                    66                Djurs  Byzone
#
#    jordstykke_ejerlavkode jordstykke_matrikelnr  jordstykke_esrejendomsnr  \
# 0               2005853.0                   6ah                   49804.0
#
#             kvh  højde                        adgangspunktid  \
# 0  07077043__26    6.5  482863a2-f005-4ecd-8e07-e20b1b058fd6
#
#                             vejpunkt_id vejpunkt_kilde vejpunkt_nøjagtighed  \
# 0  2001b328-af45-11e7-847e-066cff24d637     Adressemyn                    A
#
#   vejpunkt_tekniskstandard  vejpunkt_x  vejpunkt_y  afstemningsområdenummer  \
# 0                       V0   10.902653   56.415582                        4
#
#   afstemningsområdenavn  brofast  supplerendebynavn_dagi_id  \
# 0   Grenaa Idrætscenter      1.0                        NaN
#
#                         navngivenvej_id  menighedsrådsafstemningsområdenummer  \
# 0  2c6508b3-330f-4ae4-9533-8c5f5934a993                                  16.0
#
#   menighedsrådsafstemningsområdenavn            vejpunkt_ændret  \
# 0                             Grenaa  2020-01-14T10:08:38.23155
#
#             ikrafttrædelse nedlagt adgangsadresse_ikrafttrædelse  \
# 0  2016-04-14T08:43:55.757     NaN       2016-04-14T08:43:55.757
#
#   adgangsadresse_nedlagt  adgangsadresse_darstatus  darstatus  \
# 0                    NaN                         3          3
#
#    storkredsnummer storkredsnavn valglandsdelsbogstav  \
# 0                8    Østjylland                    C
#
#          valglandsdelsnavn landsdelsnuts3 landsdelsnavn  \
# 0  Midtjylland-Nordjylland          DK042    Østjylland
#
#                     betegnelse
# 0  Skolebakken 26, 8500 Grenaa
# length: 3897491
# id                      object
# status                   int64
# oprettet                object
# ændret                  object
# vejkode                  int64
#                          ...
# valglandsdelsbogstav    object
# valglandsdelsnavn       object
# landsdelsnuts3          object
# landsdelsnavn           object
# betegnelse              object
# Length: 83, dtype: object

# %%
DAGI_df.dtypes

# %% [markdown]
# #### Connecting to local my-sql-server and creating a table

# %%
import mysql.connector

# Replace the following details with your actual credentials
host = 'localhost'
user = 'root'
password = '1234'
database = 'bolig'  # Replace 'bolig' with the name of your database

# SQL query to create the table
create_table_query = """
    CREATE TABLE IF NOT EXISTS DAGI (
        id VARCHAR(255),
        status INT,
        oprettet VARCHAR(255),
        ændret VARCHAR(255),
        vejkode INT,
        vejnavn VARCHAR(255),
        adresseringsvejnavn VARCHAR(255),
        husnr VARCHAR(255),
        etage VARCHAR(255),
        dør VARCHAR(255),
        supplerendebynavn VARCHAR(255),
        postnr INT,
        postnrnavn VARCHAR(255),
        stormodtagerpostnr FLOAT,
        stormodtagerpostnrnavn VARCHAR(255),
        kommunekode INT,
        kommunenavn VARCHAR(255),
        ejerlavkode FLOAT,
        ejerlavnavn VARCHAR(255),
        matrikelnr VARCHAR(255),
        esrejendomsnr FLOAT,
        etrs89koordinat_øst FLOAT,
        etrs89koordinat_nord FLOAT,
        wgs84koordinat_bredde FLOAT,
        wgs84koordinat_længde FLOAT,
        nøjagtighed VARCHAR(255),
        kilde FLOAT,
        tekniskstandard VARCHAR(255),
        tekstretning FLOAT,
        ddkn_m100 VARCHAR(255),
        ddkn_km1 VARCHAR(255),
        ddkn_km10 VARCHAR(255),
        adressepunktændringsdato VARCHAR(255),
        adgangsadresseid VARCHAR(255),
        adgangsadresse_status INT,
        adgangsadresse_oprettet VARCHAR(255),
        adgangsadresse_ændret VARCHAR(255),
        regionskode INT,
        regionsnavn VARCHAR(255),
        jordstykke_ejerlavnavn VARCHAR(255),
        kvhx VARCHAR(255),
        sognekode INT,
        sognenavn VARCHAR(255),
        politikredskode INT,
        politikredsnavn VARCHAR(255),
        retskredskode INT,
        retskredsnavn VARCHAR(255),
        opstillingskredskode INT,
        opstillingskredsnavn VARCHAR(255),
        zone VARCHAR(255),
        jordstykke_ejerlavkode FLOAT,
        jordstykke_matrikelnr VARCHAR(255),
        jordstykke_esrejendomsnr FLOAT,
        kvh VARCHAR(255),
        højde FLOAT,
        adgangspunktid VARCHAR(255),
        vejpunkt_id VARCHAR(255),
        vejpunkt_kilde VARCHAR(255),
        vejpunkt_nøjagtighed VARCHAR(255),
        vejpunkt_tekniskstandard VARCHAR(255),
        vejpunkt_x FLOAT,
        vejpunkt_y FLOAT,
        afstemningsområdenummer INT,
        afstemningsområdenavn VARCHAR(255),
        brofast FLOAT,
        supplerendebynavn_dagi_id FLOAT,
        navngivenvej_id VARCHAR(255),
        menighedsrådsafstemningsområdenummer FLOAT,
        menighedsrådsafstemningsområdenavn VARCHAR(255),
        vejpunkt_ændret VARCHAR(255),
        ikrafttrædelse VARCHAR(255),
        nedlagt VARCHAR(255),
        adgangsadresse_ikrafttrædelse VARCHAR(255),
        adgangsadresse_nedlagt VARCHAR(255),
        adgangsadresse_darstatus INT,
        darstatus INT,
        storkredsnummer INT,
        storkredsnavn VARCHAR(255),
        valglandsdelsbogstav VARCHAR(255),
        valglandsdelsnavn VARCHAR(255),
        landsdelsnuts3 VARCHAR(255),
        landsdelsnavn VARCHAR(255),
        betegnelse VARCHAR(255)
    );

"""

# Establish the connection and create the table
try:
    connection = mysql.connector.connect(host=host, user=user, password=password, database=database)
    if connection.is_connected():
        print("Connected to MySQL database")
        cursor = connection.cursor()
        cursor.execute(create_table_query)
        print("Table DAGI created successfully")
        cursor.close()
    else:
        print("Failed to connect to MySQL database")

except mysql.connector.Error as err:
    print(f"Error: {err}")

finally:
    # Close the connection when done
    if 'connection' in locals():
        connection.close()
        print("Connection closed.")
# Out:
# Connected to MySQL database
# Table DAGI created successfully
# Connection closed.

# %% [markdown]
# #### Loading dataframe into sql database

# %%
import mysql.connector
import pandas as pd
from sqlalchemy import create_engine

# Replace the following details with your actual credentials
host = 'localhost'
user = 'root'
password = '1234'
database = 'bolig'

# Define the chunk size
chunk_size = 100
# Establish the connection
try:
    connection = mysql.connector.connect(host=host, user=user, password=password, database=database, connection_timeout=5000)
    if connection.is_connected():
        print("Connected to MySQL database")

        # Create an SQLAlchemy engine
        engine = create_engine(f"mysql+mysqlconnector://{user}:{password}@{host}/{database}")

        # Calculate the number of chunks needed
        num_chunks = len(DAGI_df) // chunk_size + 1

        # Load data into the database in chunks using the Pandas to_sql() method
        table_name = 'dagi'
        for i in range(num_chunks):
            start_idx = i * chunk_size
            end_idx = (i + 1) * chunk_size
            chunk = DAGI_df.iloc[start_idx:end_idx]
            chunk.to_sql(name=table_name, con=engine, if_exists='append', index=False)
            print(f"Chunk {i + 1}/{num_chunks} uploaded successfully")

        print("Data loaded into the table in chunks successfully")

except mysql.connector.Error as err:
    print(f"Error: {err}")

finally:
    # Close the connection when done
    if 'connection' in locals():
        connection.close()
        print("Connection closed.")
# Out:
# Connected to MySQL database
# Chunk 1/38975 uploaded successfully
# Chunk 2/38975 uploaded successfully
# Chunk 3/38975 uploaded successfully
# Chunk 4/38975 uploaded successfully
# Chunk 5/38975 uploaded successfully
# %% [markdown]
# ### Land (Jordstykker), data collection

# %%
# Define a function to make an API request to the Danish API for land data
def land_data_call(kommunekode):
  
    # URL for API
    url = f"https://api.dataforsyningen.dk/jordstykker?kommunekode={kommunekode}&format=csv"

    # Make a GET request to the API and read the response as a DataFrame
    load_land_data = pd.read_csv(url, low_memory=False)
    return load_land_data

# Empty list to store the dataframes
land_data_frame_list = []

# Loop through the kommune codes in region hovedstaden and make an API request for each kommune and fetch the data
for kommune in region_hovedstad_kommunekode_list:
    land_data = land_data_call(kommune)
    land_data_frame_list.append(land_data)
    
# concatenate all the dataframes into one dataframe
all_land_df = pd.concat(land_data_frame_list, axis=0, ignore_index=True)

display(all_land_df.head())
print("Length:", len(all_land_df))
# Out:
#                      ændret                geo_ændret  geo_version  bbox_xmin  \
# 0  2023-03-29T21:04:30.316Z  2015-02-27T20:24:00.545Z            1  12.347892
# 1  2023-03-29T21:04:30.316Z  2015-02-27T20:24:00.545Z            1  12.341121
# 2  2023-03-29T21:04:30.316Z  2022-07-13T21:48:52.247Z            4  12.358818
# 3  2023-05-09T21:46:11.428Z  2023-05-09T21:46:11.428Z            5  12.360630
# 4  2023-05-09T21:46:11.428Z  2023-05-09T21:46:11.428Z            2  12.360788
#
#    bbox_ymin  bbox_xmax  bbox_ymax  visueltcenter_x  visueltcenter_y  \
# 0  55.673141  12.350759  55.674584        12.348973        55.673985
# 1  55.664756  12.342912  55.665700        12.341721        55.665352
# 2  55.658780  12.362671  55.660253        12.359989        55.659484
# 3  55.670630  12.365362  55.674651        12.363326        55.673775
# 4  55.671963  12.362603  55.673198        12.361809        55.672650
#
#    ejerlavkode matrikelnr  kommunekode  kommunenavn  sognekode  \
# 0        20551       11am          165  Albertslund       7148
# 1        20551        12s          165  Albertslund       7155
# 2        20551       15ak          165  Albertslund       9134
# 3        20652        10a          165  Albertslund       7148
# 4        20652       10dn          165  Albertslund       7148
#
#              sognenavn  regionskode         regionsnavn  retskredskode  \
# 0         Herstedøster         1084  Region Hovedstaden              0
# 1        Herstedvester         1084  Region Hovedstaden              0
# 2  Opstandelseskirkens         1084  Region Hovedstaden              0
# 3         Herstedøster         1084  Region Hovedstaden              0
# 4         Herstedøster         1084  Region Hovedstaden              0
#
#    retskredsnavn  udvidet_esrejendomsnr  esrejendomsnr  sfeejendomsnr  \
# 0            NaN           1.650057e+09        57236.0        1302759
# 1            NaN           1.650059e+09        58771.0        9874836
# 2            NaN           1.650066e+09        66019.0      100095931
# 3            NaN           1.650036e+09        36042.0        2126175
# 4            NaN           1.650066e+09        66024.0      100174931
#
#      bfenummer                      ejerlavnavn  featureid  fælleslod  \
# 0    1302759.0  Herstedvester By, Herstedvester     999291        NaN
# 1    9874836.0  Herstedvester By, Herstedvester    2647884        NaN
# 2  100095931.0  Herstedvester By, Herstedvester  100107370        NaN
# 3    2126175.0    Herstedøster By, Herstedøster    1001576        NaN
# 4  100174931.0    Herstedøster By, Herstedøster  100195210        NaN
#
#    moderjordstykke  registreretareal arealberegningsmetode  vejareal  \
# 0              NaN             13141                     o      3160
# 1              NaN              2393                     o      1182
# 2              NaN             13755                     o      7020
# 3              NaN             50472                     k       314
# 4        1001576.0             10584                     o       780
#
#   vejarealberegningsmetode vandarealberegningsmetode
# 0                        b                    ukendt
# 1                        b                    ukendt
# 2                        b                    ukendt
# 3                        b                      incl
# 4                        b                    ukendt
# Length: 346347

# %% [markdown]
# ## BBR.info

# %% [markdown]
# Hente BBR info ud fra kommune kode

# %%
import requests
import pandas as pd

# Set the API URL
api_url = "https://services.datafordeler.dk/BBR/BBRPublic/1/rest/enhed"

# Function to fetch data
def fetch_data(kommunekode):
    # Set the parameters
    params = {
        "username": "ANLVUSSNAP",
        "password": "Essvietcc567!",
        "Format": "JSON",
        "Kommunekode": kommunekode,
        "pagesize": 9999999,  # Specify the maximum page size
        "page": 1  # Request the first page
    }

    # Fetch data from the API
    response = requests.get(api_url, params=params)

    # Check the status code and proceed with processing the response
    if response.status_code == 200:
        try:
            data = response.json()
            df = pd.DataFrame(data)
            return df

        except ValueError as e:
            print(f"Failed to decode JSON for kommunekode {kommunekode}.")
            return None

    else:
        print(f"Failed to fetch data for kommunekode {kommunekode} from the API. Status code: {response.status_code}")
        return None

# List of kommunekode values to iterate over
kommunekode_list = ['0165', '0201', '0151', '0153', '0155', '0240', '0210', '0147', '0250', '0190', '0157', '0159', '0161', '0270', '0217', '0163', '0219', '0167', '0169', '0223', '0183', '0101', '0230', '0175', '0185', '0187']


# Initialize an empty list to store the DataFrames
dataframes = []

# Fetch data for each kommunekode
for kommunekode in kommunekode_list:
    df = fetch_data(kommunekode)
    if df is not None:
        dataframes.append(df)

# Concatenate all the dataframes in the list
final_df = pd.concat(dataframes)

# Save the DataFrame to a pickle file
final_df.to_pickle(r"C:\Users\viet-intel\boligpriser\data\output\bbr_enhed.pkl")

# Display the first few rows and the total length of the final DataFrame
display(final_df.head())
print("Length:", len(final_df))

# %%
# Load pickle file
bbr_df = pd.read_pickle(r"C:\Users\viet-intel\boligpriser\data\output\bbr_enhed.pkl")

print(len(bbr_df))

bbr_df.head(3)
# Out:
# 1165203
#          datafordelerOpdateringstid                  adresseIdentificerer  \
# 0  2021-04-03T17:52:53.115133+02:00  0a3f50a5-3c61-32b8-e044-0003ba298018
# 1  2023-02-27T15:07:49.672495+01:00  0a3f50a5-3b93-32b8-e044-0003ba298018
# 2  2023-02-27T15:20:40.813256+01:00  0a3f50a5-3b5e-32b8-e044-0003ba298018
#
#   enh020EnhedensAnvendelse enh023Boligtype  enh026EnhedensSamledeAreal  \
# 0                      130               1                       106.0
# 1                      150               3                        29.0
# 2                      150               3                        29.0
#
#    enh027ArealTilBeboelse enh030KildeTilEnhedensArealer  enh031AntalVærelser  \
# 0                   106.0                             1                  4.0
# 1                    29.0                             1                  1.0
# 2                    29.0                             1                  1.0
#
#   enh032Toiletforhold enh033Badeforhold enh034Køkkenforhold  \
# 0                   T                 V                   E
# 1                   T                 V                   F
# 2                   T                 V                   F
#
#   enh045Udlejningsforhold enh048GodkendtTomBolig  \
# 0                       1                      0
# 1                       1                      0
# 2                       1                      0
#
#    enh065AntalVandskylledeToiletter  enh066AntalBadeværelser  \
# 0                               1.0                      1.0
# 1                               1.0                      1.0
# 2                               1.0                      1.0
#
#   enh071AdresseFunktion                                 etage  \
# 0                     0  c0034a30-e3a9-47db-8df8-fc09ac978e06
# 1                     1  be4164f9-4c7c-4a62-8ca1-139a383656af
# 2                     1  1aca0cd2-6782-436f-ada9-154aec8f4364
#
#   forretningshændelse forretningsområde forretningsproces  \
# 0               Enhed       54.15.05.05                 0
# 1               Enhed       54.15.05.05                 4
# 2               Enhed       54.15.05.05                 4
#
#                              id_lokalId                  id_namespace  \
# 0  000146fc-eb6d-449e-9ecd-a90bea4b6963  http://data.gov.dk/bbr/enhed
# 1  00019635-4426-4b7f-9afc-9623facdc80f  http://data.gov.dk/bbr/enhed
# 2  0004658e-4916-4ef6-bc67-0973bde1ba24  http://data.gov.dk/bbr/enhed
#
#   kommunekode                                opgang  \
# 0        0165  01e09215-259d-4a33-a16c-545e8300059c
# 1        0165  b46abcef-2997-4b1f-b108-05c2e7125a30
# 2        0165  0dd607ca-5d1b-474e-8f70-63d4507948a6
#
#                     registreringFra registreringsaktør status  \
# 0  2018-09-14T19:31:21.793333+02:00                BBR      6
# 1  2023-02-27T15:07:24.284866+01:00                BBR     10
# 2  2023-02-27T15:20:17.927211+01:00                BBR     10
#
#                         virkningFra virkningsaktør  \
# 0  2018-09-14T19:31:21.793333+02:00            BBR
# 1  2023-02-27T15:07:24.284866+01:00  Registerfører
# 2  2023-02-27T15:20:17.927211+01:00  Registerfører
#
#                                 bygning enh024KondemneretBoligenhed  \
# 0  643e4ffe-60ce-40d4-aec3-7f8e93709897                         NaN
# 1  c5b3d260-7dd6-4179-a43b-2b267354383b                           0
# 2  f3cd9fa9-407b-47d2-8026-c99922b48038                           0
#
#    enh067Støjisolering enh025OprettelsesdatoForEnhedensIdentifikation  \
# 0                  NaN                                            NaN
# 1                  NaN                                            NaN
# 2               1989.0                                            NaN
#
#   enh035Energiforsyning ejerlejlighedList  enh028ArealTilErhverv  \
# 0                   NaN               NaN                    NaN
# 1                   NaN               NaN                    NaN
# 2                   NaN               NaN                    NaN
#
#   enh046OffentligStøtte  enh063AntalVærelserTilErhverv enh101Gyldighedsdato  \
# 0                   NaN                            NaN                  NaN
# 1                   NaN                            NaN                  NaN
# 2                   NaN                            NaN                  NaN
#
#    enh060EnhedensAndelFællesAdgangsareal  enh070ÅbenAltanTagterrasseAreal  \
# 0                                    NaN                              NaN
# 1                                    NaN                              NaN
# 2                                    NaN                              NaN
#
#   enh051Varmeinstallation enh068FlexboligTilladelsesart  \
# 0                     NaN                           NaN
# 1                     NaN                           NaN
# 2                     NaN                           NaN
#
#    enh127FysiskArealTilBeboelse fordelingsarealList enh053SupplerendeVarme  \
# 0                           NaN                 NaN                    NaN
# 1                           NaN                 NaN                    NaN
# 2                           NaN                 NaN                    NaN
#
#    enh062ArealAfLukketOverdækningUdestue enh052Opvarmningsmiddel  \
# 0                                    NaN                     NaN
# 1                                    NaN                     NaN
# 2                                    NaN                     NaN
#
#    enh039AndetAreal enh047IndflytningDato enh041LovligAnvendelse  \
# 0               NaN                   NaN                    NaN
# 1               NaN                   NaN                    NaN
# 2               NaN                   NaN                    NaN
#
#   enh044DatoForDelvisIbrugtagningsTilladelse  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
#
#   enh042DatoForTidsbegrænsetDispensation enh008UUIDTilModerlejlighed  \
# 0                                    NaN                         NaN
# 1                                    NaN                         NaN
# 2                                    NaN                         NaN
#
#    enh128FysiskArealTilErhverv
# 0                          NaN
# 1                          NaN
# 2                          NaN

# %%
columns = ['datafordelerOpdateringstid', 'adresseIdentificerer', 'enh020EnhedensAnvendelse', 'enh023Boligtype', 
           'enh026EnhedensSamledeAreal', 'enh027ArealTilBeboelse', 'enh030KildeTilEnhedensArealer', 'enh031AntalVærelser', 
           'enh032Toiletforhold', 'enh033Badeforhold', 'enh034Køkkenforhold', 'enh045Udlejningsforhold', 
           'enh048GodkendtTomBolig', 'enh065AntalVandskylledeToiletter', 'enh066AntalBadeværelser', 'enh071AdresseFunktion', 
           'etage', 'forretningshændelse', 'forretningsområde', 'forretningsproces', 'id_lokalId', 'id_namespace', 
           'kommunekode', 'opgang', 'registreringFra', 'registreringsaktør', 'status', 'virkningFra', 'virkningsaktør', 
           'bygning', 'enh024KondemneretBoligenhed', 'enh067Støjisolering']

# Create new DataFrame with the selected columns
bbr_df = bbr_df[columns]

bbr_df.head(3)
# Out:
#          datafordelerOpdateringstid                  adresseIdentificerer  \
# 0  2021-04-03T17:52:53.115133+02:00  0a3f50a5-3c61-32b8-e044-0003ba298018
# 1  2023-02-27T15:07:49.672495+01:00  0a3f50a5-3b93-32b8-e044-0003ba298018
# 2  2023-02-27T15:20:40.813256+01:00  0a3f50a5-3b5e-32b8-e044-0003ba298018
#
#   enh020EnhedensAnvendelse enh023Boligtype  enh026EnhedensSamledeAreal  \
# 0                      130               1                       106.0
# 1                      150               3                        29.0
# 2                      150               3                        29.0
#
#    enh027ArealTilBeboelse enh030KildeTilEnhedensArealer  enh031AntalVærelser  \
# 0                   106.0                             1                  4.0
# 1                    29.0                             1                  1.0
# 2                    29.0                             1                  1.0
#
#   enh032Toiletforhold enh033Badeforhold enh034Køkkenforhold  \
# 0                   T                 V                   E
# 1                   T                 V                   F
# 2                   T                 V                   F
#
#   enh045Udlejningsforhold enh048GodkendtTomBolig  \
# 0                       1                      0
# 1                       1                      0
# 2                       1                      0
#
#    enh065AntalVandskylledeToiletter  enh066AntalBadeværelser  \
# 0                               1.0                      1.0
# 1                               1.0                      1.0
# 2                               1.0                      1.0
#
#   enh071AdresseFunktion                                 etage  \
# 0                     0  c0034a30-e3a9-47db-8df8-fc09ac978e06
# 1                     1  be4164f9-4c7c-4a62-8ca1-139a383656af
# 2                     1  1aca0cd2-6782-436f-ada9-154aec8f4364
#
#   forretningshændelse forretningsområde forretningsproces  \
# 0               Enhed       54.15.05.05                 0
# 1               Enhed       54.15.05.05                 4
# 2               Enhed       54.15.05.05                 4
#
#                              id_lokalId                  id_namespace  \
# 0  000146fc-eb6d-449e-9ecd-a90bea4b6963  http://data.gov.dk/bbr/enhed
# 1  00019635-4426-4b7f-9afc-9623facdc80f  http://data.gov.dk/bbr/enhed
# 2  0004658e-4916-4ef6-bc67-0973bde1ba24  http://data.gov.dk/bbr/enhed
#
#   kommunekode                                opgang  \
# 0        0165  01e09215-259d-4a33-a16c-545e8300059c
# 1        0165  b46abcef-2997-4b1f-b108-05c2e7125a30
# 2        0165  0dd607ca-5d1b-474e-8f70-63d4507948a6
#
#                     registreringFra registreringsaktør status  \
# 0  2018-09-14T19:31:21.793333+02:00                BBR      6
# 1  2023-02-27T15:07:24.284866+01:00                BBR     10
# 2  2023-02-27T15:20:17.927211+01:00                BBR     10
#
#                         virkningFra virkningsaktør  \
# 0  2018-09-14T19:31:21.793333+02:00            BBR
# 1  2023-02-27T15:07:24.284866+01:00  Registerfører
# 2  2023-02-27T15:20:17.927211+01:00  Registerfører
#
#                                 bygning enh024KondemneretBoligenhed  \
# 0  643e4ffe-60ce-40d4-aec3-7f8e93709897                         NaN
# 1  c5b3d260-7dd6-4179-a43b-2b267354383b                           0
# 2  f3cd9fa9-407b-47d2-8026-c99922b48038                           0
#
#    enh067Støjisolering
# 0                  NaN
# 1                  NaN
# 2               1989.0

# %% [markdown]
# Load til SQL

# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine, types
from math import ceil

# MySQL connection setup
username = 'root'
password = '1234'
host = 'localhost'
database = 'bolig'

engine_str = f"mysql+mysqlconnector://{username}:{password}@{host}/{database}"
engine = create_engine(engine_str)

# Fetching the dtypes for each column
dtype_dict = bbr_df.dtypes.apply(lambda x: types.TEXT 
                                  if x == "object" 
                                  else types.Float(precision=3, asdecimal=True) 
                                  if x == "float" 
                                  else types.Integer()).to_dict()

# Create table if doesn't exist
bbr_df[:0].to_sql('bbr', con=engine, if_exists='replace', dtype=dtype_dict)

# Upload data in chunks
n = 1000  # chunk row size
total_chunks = ceil(len(bbr_df) / n)

for i in range(total_chunks):
    print(f'Uploading chunk {i+1}/{total_chunks}...')
    bbr_df[i*n:(i+1)*n].to_sql('bbr', con=engine, if_exists='append', dtype=dtype_dict)
    
print("Upload complete.")

# %% [markdown]
# ## DAR

# %% [markdown]
# DAR information ud fra kommune kode

# %%
import os
import requests
import pandas as pd
import time

# Set the API URL
api_url = "https://services.datafordeler.dk/DAR/DAR/2.0.0/rest/adresse"

# Function to fetch data
def fetch_data(kommunekode):
    # Set the parameters
    params = {
        "username": "ANLVUSSNAP",
        "password": "Essvietcc567!",
        "Format": "JSON",
        "Kommunekode": kommunekode,
        "pagesize": 100000,  # Specify a reasonable page size
    }
    
    # Initialize an empty list to store the DataFrames
    dataframes = []
    
    # Initialize the page
    page = 1

    while True:
        # Update the 'page' parameter
        params["page"] = page

        # Fetch data from the API
        response = requests.get(api_url, params=params)
        time.sleep(1)  # Sleep for 1 second to prevent hitting rate limit

        # Check the status code and proceed with processing the response
        if response.status_code == 200:
            try:
                data = response.json()
                if not data:  # Break the loop if the data list is empty
                    break
                df = pd.DataFrame(data)
                dataframes.append(df)

            except ValueError as e:
                print(f"Failed to decode JSON for kommunekode {kommunekode}.")
                return None

        else:
            print(f"Failed to fetch data for kommunekode {kommunekode} from the API. Status code: {response.status_code}")
            return None
        
        # Increment the page number
        page += 1
    
    # Concatenate all dataframes
    if dataframes:
        return pd.concat(dataframes)
    else:
        return None

# List of kommunekode values to iterate over
kommunekode_list = ['0101'] 

# Output directory
output_dir = r'C:\Users\viet-intel\boligpriser\data\output\Hovedstad'

# Fetch data for each kommunekode
for kommunekode in kommunekode_list:
    df = fetch_data(kommunekode)
    if df is not None:
        # Print the length of the DataFrame
        print(f'Length of DataFrame for kommunekode {kommunekode}: {len(df)}')

        # Save the DataFrame to a pickle file
        pickle_file = os.path.join(output_dir, f'kommune_{kommunekode}.pkl')
        df.to_pickle(pickle_file)

print("Data saved to individual pickle files.")
# Out:
# Length of DataFrame for kommunekode 0101: 464484
# Data saved to individual pickle files.

# %% [markdown]
# Sammensætning af forskellige pkl filer

# %%
import glob
import pandas as pd
import os

# Directory containing the pickle files
input_dir = r'C:\Users\viet-intel\boligpriser\data\output\Hovedstad'

# Output directory for the combined pickle file
output_dir = r'C:\Users\viet-intel\boligpriser\data\output'

# Get a list of all pickle files in the directory
pickle_files = glob.glob(os.path.join(input_dir, '*.pkl'))

# Load the data from each pickle file and store it in a list
dataframes = [pd.read_pickle(pickle_file) for pickle_file in pickle_files]

# Concatenate all dataframes into one
dar_df = pd.concat(dataframes, ignore_index=True)

# Save the combined DataFrame to a new pickle file
output_file = os.path.join(output_dir, 'DAR.pkl')
dar_df.to_pickle(output_file)

# Print the length of the combined DataFrame
print(f'Length of combined DataFrame: {len(dar_df)}')

print(f"Combined data saved to {output_file}.")
# Out:
# Length of combined DataFrame: 1144796
# Combined data saved to C:\Users\viet-intel\boligpriser\data\output\DAR.pkl.

# %%
dar_df.drop(columns=['husnummer'], inplace=True)

# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine, types
from math import ceil

# MySQL connection setup
username = 'root'
password = '1234'
host = 'localhost'
database = 'bolig'

engine_str = f"mysql+mysqlconnector://{username}:{password}@{host}/{database}"
engine = create_engine(engine_str)

# Fetching the dtypes for each column
dtype_dict = dar_df.dtypes.map(lambda x: types.TEXT 
                                  if x == "object" 
                                  else types.Float(precision=3, asdecimal=True) 
                                  if x == "float" 
                                  else types.Integer()).to_dict()

# Create table if doesn't exist
dar_df[:0].to_sql('dar', con=engine, if_exists='replace', dtype=dtype_dict)

# Upload data in chunks
n = 1000  # chunk row size
total_chunks = ceil(len(dar_df) / n)

for i in range(total_chunks):
    print(f'Uploading chunk {i+1}/{total_chunks}...')
    dar_df[i*n:(i+1)*n].to_sql('dar', con=engine, if_exists='append', dtype=dtype_dict)
    
print("Upload complete.")
# Out:
# Uploading chunk 1/1145...
# Uploading chunk 2/1145...
# Uploading chunk 3/1145...
# Uploading chunk 4/1145...
# Uploading chunk 5/1145...
# Uploading chunk 6/1145...
# Uploading chunk 7/1145...
# Uploading chunk 8/1145...
# Uploading chunk 9/1145...
# Uploading chunk 10/1145...
# Uploading chunk 11/1145...
# Uploading chunk 12/1145...
# Uploading chunk 13/1145...
# Uploading chunk 14/1145...
# Uploading chunk 15/1145...
# Uploading chunk 16/1145...
# Uploading chunk 17/1145...
# Uploading chunk 18/1145...
# Uploading chunk 19/1145...
# Uploading chunk 20/1145...
# Uploading chunk 21/1145...
# Uploading chunk 22/1145...
# Uploading chunk 23/1145...
# Uploading chunk 24/1145...
# Uploading chunk 25/1145...
# Uploading chunk 26/1145...
# Uploading chunk 27/1145...
# Uploading chunk 28/1145...
# Uploading chunk 29/1145...
# Uploading chunk 30/1145...
# Uploading chunk 31/1145...
# Uploading chunk 32/1145...
# Uploading chunk 33/1145...
# Uploading chunk 34/1145...
# Uploading chunk 35/1145...
# Uploading chunk 36/1145...
# Uploading chunk 37/1145...
# Uploading chunk 38/1145...
# Uploading chunk 39/1145...
# Uploading chunk 40/1145...
# Uploading chunk 41/1145...
# Uploading chunk 42/1145...
# Uploading chunk 43/1145...
# Uploading chunk 44/1145...
# Uploading chunk 45/1145...
# Uploading chunk 46/1145...
# Uploading chunk 47/1145...
# Uploading chunk 48/1145...
# Uploading chunk 49/1145...
# Uploading chunk 50/1145...
# Uploading chunk 51/1145...
# Uploading chunk 52/1145...
# Uploading chunk 53/1145...
# Uploading chunk 54/1145...
# Uploading chunk 55/1145...
# Uploading chunk 56/1145...
# Uploading chunk 57/1145...
# Uploading chunk 58/1145...
# Uploading chunk 59/1145...
# Uploading chunk 60/1145...
# Uploading chunk 61/1145...
# Uploading chunk 62/1145...
# Uploading chunk 63/1145...
# Uploading chunk 64/1145...
# Uploading chunk 65/1145...
# Uploading chunk 66/1145...
# Uploading chunk 67/1145...
# Uploading chunk 68/1145...
# Uploading chunk 69/1145...
# Uploading chunk 70/1145...
# Uploading chunk 71/1145...
# Uploading chunk 72/1145...
# Uploading chunk 73/1145...
# Uploading chunk 74/1145...
# Uploading chunk 75/1145...
# Uploading chunk 76/1145...
# Uploading chunk 77/1145...
# Uploading chunk 78/1145...
# Uploading chunk 79/1145...
# Uploading chunk 80/1145...
# Uploading chunk 81/1145...
# Uploading chunk 82/1145...
# Uploading chunk 83/1145...
# Uploading chunk 84/1145...
# Uploading chunk 85/1145...
# Uploading chunk 86/1145...
# Uploading chunk 87/1145...
# Uploading chunk 88/1145...
# Uploading chunk 89/1145...
# Uploading chunk 90/1145...
# Uploading chunk 91/1145...
# Uploading chunk 92/1145...
# Uploading chunk 93/1145...
# Uploading chunk 94/1145...
# Uploading chunk 95/1145...
# Uploading chunk 96/1145...
# Uploading chunk 97/1145...
# Uploading chunk 98/1145...
# Uploading chunk 99/1145...
# Uploading chunk 100/1145...
# Uploading chunk 101/1145...
# Uploading chunk 102/1145...
# Uploading chunk 103/1145...
# Uploading chunk 104/1145...
# Uploading chunk 105/1145...
# Uploading chunk 106/1145...
# Uploading chunk 107/1145...
# Uploading chunk 108/1145...
# Uploading chunk 109/1145...
# Uploading chunk 110/1145...
# Uploading chunk 111/1145...
# Uploading chunk 112/1145...
# Uploading chunk 113/1145...
# Uploading chunk 114/1145...
# Uploading chunk 115/1145...
# Uploading chunk 116/1145...
# Uploading chunk 117/1145...
# Uploading chunk 118/1145...
# Uploading chunk 119/1145...
# Uploading chunk 120/1145...
# Uploading chunk 121/1145...
# Uploading chunk 122/1145...
# Uploading chunk 123/1145...
# Uploading chunk 124/1145...
# Uploading chunk 125/1145...
# Uploading chunk 126/1145...
# Uploading chunk 127/1145...
# Uploading chunk 128/1145...
# Uploading chunk 129/1145...
# Uploading chunk 130/1145...
# Uploading chunk 131/1145...
# Uploading chunk 132/1145...
# Uploading chunk 133/1145...
# Uploading chunk 134/1145...
# Uploading chunk 135/1145...
# Uploading chunk 136/1145...
# Uploading chunk 137/1145...
# Uploading chunk 138/1145...
# Uploading chunk 139/1145...
# Uploading chunk 140/1145...
# Uploading chunk 141/1145...
# Uploading chunk 142/1145...
# Uploading chunk 143/1145...
# Uploading chunk 144/1145...
# Uploading chunk 145/1145...
# Uploading chunk 146/1145...
# Uploading chunk 147/1145...
# Uploading chunk 148/1145...
# Uploading chunk 149/1145...
# Uploading chunk 150/1145...
# Uploading chunk 151/1145...
# Uploading chunk 152/1145...
# Uploading chunk 153/1145...
# Uploading chunk 154/1145...
# Uploading chunk 155/1145...
# Uploading chunk 156/1145...
# Uploading chunk 157/1145...
# Uploading chunk 158/1145...
# Uploading chunk 159/1145...
# Uploading chunk 160/1145...
# Uploading chunk 161/1145...
# Uploading chunk 162/1145...
# Uploading chunk 163/1145...
# Uploading chunk 164/1145...
# Uploading chunk 165/1145...
# Uploading chunk 166/1145...
# Uploading chunk 167/1145...
# Uploading chunk 168/1145...
# Uploading chunk 169/1145...
# Uploading chunk 170/1145...
# Uploading chunk 171/1145...
# Uploading chunk 172/1145...
# Uploading chunk 173/1145...
# Uploading chunk 174/1145...
# Uploading chunk 175/1145...
# Uploading chunk 176/1145...
# Uploading chunk 177/1145...
# Uploading chunk 178/1145...
# Uploading chunk 179/1145...
# Uploading chunk 180/1145...
# Uploading chunk 181/1145...
# Uploading chunk 182/1145...
# Uploading chunk 183/1145...
# Uploading chunk 184/1145...
# Uploading chunk 185/1145...
# Uploading chunk 186/1145...
# Uploading chunk 187/1145...
# Uploading chunk 188/1145...
# Uploading chunk 189/1145...
# Uploading chunk 190/1145...
# Uploading chunk 191/1145...
# Uploading chunk 192/1145...
# Uploading chunk 193/1145...
# Uploading chunk 194/1145...
# Uploading chunk 195/1145...
# Uploading chunk 196/1145...
# Uploading chunk 197/1145...
# Uploading chunk 198/1145...
# Uploading chunk 199/1145...
# Uploading chunk 200/1145...
# Uploading chunk 201/1145...
# Uploading chunk 202/1145...
# Uploading chunk 203/1145...
# Uploading chunk 204/1145...
# Uploading chunk 205/1145...
# Uploading chunk 206/1145...
# Uploading chunk 207/1145...
# Uploading chunk 208/1145...
# Uploading chunk 209/1145...
# Uploading chunk 210/1145...
# Uploading chunk 211/1145...
# Uploading chunk 212/1145...
# Uploading chunk 213/1145...
# Uploading chunk 214/1145...
# Uploading chunk 215/1145...
# Uploading chunk 216/1145...
# Uploading chunk 217/1145...
# Uploading chunk 218/1145...
# Uploading chunk 219/1145...
# Uploading chunk 220/1145...
# Uploading chunk 221/1145...
# Uploading chunk 222/1145...
# Uploading chunk 223/1145...
# Uploading chunk 224/1145...
# Uploading chunk 225/1145...
# Uploading chunk 226/1145...
# Uploading chunk 227/1145...
# Uploading chunk 228/1145...
# Uploading chunk 229/1145...
# Uploading chunk 230/1145...
# Uploading chunk 231/1145...
# Uploading chunk 232/1145...
# Uploading chunk 233/1145...
# Uploading chunk 234/1145...
# Uploading chunk 235/1145...
# Uploading chunk 236/1145...
# Uploading chunk 237/1145...
# Uploading chunk 238/1145...
# Uploading chunk 239/1145...
# Uploading chunk 240/1145...
# Uploading chunk 241/1145...
# Uploading chunk 242/1145...
# Uploading chunk 243/1145...
# Uploading chunk 244/1145...
# Uploading chunk 245/1145...
# Uploading chunk 246/1145...
# Uploading chunk 247/1145...
# Uploading chunk 248/1145...
# Uploading chunk 249/1145...
# Uploading chunk 250/1145...
# Uploading chunk 251/1145...
# Uploading chunk 252/1145...
# Uploading chunk 253/1145...
# Uploading chunk 254/1145...
# Uploading chunk 255/1145...
# Uploading chunk 256/1145...
# Uploading chunk 257/1145...
# Uploading chunk 258/1145...
# Uploading chunk 259/1145...
# Uploading chunk 260/1145...
# Uploading chunk 261/1145...
# Uploading chunk 262/1145...
# Uploading chunk 263/1145...
# Uploading chunk 264/1145...
# Uploading chunk 265/1145...
# Uploading chunk 266/1145...
# Uploading chunk 267/1145...
# Uploading chunk 268/1145...
# Uploading chunk 269/1145...
# Uploading chunk 270/1145...
# Uploading chunk 271/1145...
# Uploading chunk 272/1145...
# Uploading chunk 273/1145...
# Uploading chunk 274/1145...
# Uploading chunk 275/1145...
# Uploading chunk 276/1145...
# Uploading chunk 277/1145...
# Uploading chunk 278/1145...
# Uploading chunk 279/1145...
# Uploading chunk 280/1145...
# Uploading chunk 281/1145...
# Uploading chunk 282/1145...
# Uploading chunk 283/1145...
# Uploading chunk 284/1145...
# Uploading chunk 285/1145...
# Uploading chunk 286/1145...
# Uploading chunk 287/1145...
# Uploading chunk 288/1145...
# Uploading chunk 289/1145...
# Uploading chunk 290/1145...
# Uploading chunk 291/1145...
# Uploading chunk 292/1145...
# Uploading chunk 293/1145...
# Uploading chunk 294/1145...
# Uploading chunk 295/1145...
# Uploading chunk 296/1145...
# Uploading chunk 297/1145...
# Uploading chunk 298/1145...
# Uploading chunk 299/1145...
# Uploading chunk 300/1145...
# Uploading chunk 301/1145...
# Uploading chunk 302/1145...
# Uploading chunk 303/1145...
# Uploading chunk 304/1145...
# Uploading chunk 305/1145...
# Uploading chunk 306/1145...
# Uploading chunk 307/1145...
# Uploading chunk 308/1145...
# Uploading chunk 309/1145...
# Uploading chunk 310/1145...
# Uploading chunk 311/1145...
# Uploading chunk 312/1145...
# Uploading chunk 313/1145...
# Uploading chunk 314/1145...
# Uploading chunk 315/1145...
# Uploading chunk 316/1145...
# Uploading chunk 317/1145...
# Uploading chunk 318/1145...
# Uploading chunk 319/1145...
# Uploading chunk 320/1145...
# Uploading chunk 321/1145...
# Uploading chunk 322/1145...
# Uploading chunk 323/1145...
# Uploading chunk 324/1145...
# Uploading chunk 325/1145...
# Uploading chunk 326/1145...
# Uploading chunk 327/1145...
# Uploading chunk 328/1145...
# Uploading chunk 329/1145...
# Uploading chunk 330/1145...
# Uploading chunk 331/1145...
# Uploading chunk 332/1145...
# Uploading chunk 333/1145...
# Uploading chunk 334/1145...
# Uploading chunk 335/1145...
# Uploading chunk 336/1145...
# Uploading chunk 337/1145...
# Uploading chunk 338/1145...
# Uploading chunk 339/1145...
# Uploading chunk 340/1145...
# Uploading chunk 341/1145...
# Uploading chunk 342/1145...
# Uploading chunk 343/1145...
# Uploading chunk 344/1145...
# Uploading chunk 345/1145...
# Uploading chunk 346/1145...
# Uploading chunk 347/1145...
# Uploading chunk 348/1145...
# Uploading chunk 349/1145...
# Uploading chunk 350/1145...
# Uploading chunk 351/1145...
# Uploading chunk 352/1145...
# Uploading chunk 353/1145...
# Uploading chunk 354/1145...
# Uploading chunk 355/1145...
# Uploading chunk 356/1145...
# Uploading chunk 357/1145...
# Uploading chunk 358/1145...
# Uploading chunk 359/1145...
# Uploading chunk 360/1145...
# Uploading chunk 361/1145...
# Uploading chunk 362/1145...
# Uploading chunk 363/1145...
# Uploading chunk 364/1145...
# Uploading chunk 365/1145...
# Uploading chunk 366/1145...
# Uploading chunk 367/1145...
# Uploading chunk 368/1145...
# Uploading chunk 369/1145...
# Uploading chunk 370/1145...
# Uploading chunk 371/1145...
# Uploading chunk 372/1145...
# Uploading chunk 373/1145...
# Uploading chunk 374/1145...
# Uploading chunk 375/1145...
# Uploading chunk 376/1145...
# Uploading chunk 377/1145...
# Uploading chunk 378/1145...
# Uploading chunk 379/1145...
# Uploading chunk 380/1145...
# Uploading chunk 381/1145...
# Uploading chunk 382/1145...
# Uploading chunk 383/1145...
# Uploading chunk 384/1145...
# Uploading chunk 385/1145...
# Uploading chunk 386/1145...
# Uploading chunk 387/1145...
# Uploading chunk 388/1145...
# Uploading chunk 389/1145...
# Uploading chunk 390/1145...
# Uploading chunk 391/1145...
# Uploading chunk 392/1145...
# Uploading chunk 393/1145...
# Uploading chunk 394/1145...
# Uploading chunk 395/1145...
# Uploading chunk 396/1145...
# Uploading chunk 397/1145...
# Uploading chunk 398/1145...
# Uploading chunk 399/1145...
# Uploading chunk 400/1145...
# Uploading chunk 401/1145...
# Uploading chunk 402/1145...
# Uploading chunk 403/1145...
# Uploading chunk 404/1145...
# Uploading chunk 405/1145...
# Uploading chunk 406/1145...
# Uploading chunk 407/1145...
# Uploading chunk 408/1145...
# Uploading chunk 409/1145...
# Uploading chunk 410/1145...
# Uploading chunk 411/1145...
# Uploading chunk 412/1145...
# Uploading chunk 413/1145...
# Uploading chunk 414/1145...
# Uploading chunk 415/1145...
# Uploading chunk 416/1145...
# Uploading chunk 417/1145...
# Uploading chunk 418/1145...
# Uploading chunk 419/1145...
# Uploading chunk 420/1145...
# Uploading chunk 421/1145...
# Uploading chunk 422/1145...
# Uploading chunk 423/1145...
# Uploading chunk 424/1145...
# Uploading chunk 425/1145...
# Uploading chunk 426/1145...
# Uploading chunk 427/1145...
# Uploading chunk 428/1145...
# Uploading chunk 429/1145...
# Uploading chunk 430/1145...
# Uploading chunk 431/1145...
# Uploading chunk 432/1145...
# Uploading chunk 433/1145...
# Uploading chunk 434/1145...
# Uploading chunk 435/1145...
# Uploading chunk 436/1145...
# Uploading chunk 437/1145...
# Uploading chunk 438/1145...
# Uploading chunk 439/1145...
# Uploading chunk 440/1145...
# Uploading chunk 441/1145...
# Uploading chunk 442/1145...
# Uploading chunk 443/1145...
# Uploading chunk 444/1145...
# Uploading chunk 445/1145...
# Uploading chunk 446/1145...
# Uploading chunk 447/1145...
# Uploading chunk 448/1145...
# Uploading chunk 449/1145...
# Uploading chunk 450/1145...
# Uploading chunk 451/1145...
# Uploading chunk 452/1145...
# Uploading chunk 453/1145...
# Uploading chunk 454/1145...
# Uploading chunk 455/1145...
# Uploading chunk 456/1145...
# Uploading chunk 457/1145...
# Uploading chunk 458/1145...
# Uploading chunk 459/1145...
# Uploading chunk 460/1145...
# Uploading chunk 461/1145...
# Uploading chunk 462/1145...
# Uploading chunk 463/1145...
# Uploading chunk 464/1145...
# Uploading chunk 465/1145...
# Uploading chunk 466/1145...
# Uploading chunk 467/1145...
# Uploading chunk 468/1145...
# Uploading chunk 469/1145...
# Uploading chunk 470/1145...
# Uploading chunk 471/1145...
# Uploading chunk 472/1145...
# Uploading chunk 473/1145...
# Uploading chunk 474/1145...
# Uploading chunk 475/1145...
# Uploading chunk 476/1145...
# Uploading chunk 477/1145...
# Uploading chunk 478/1145...
# Uploading chunk 479/1145...
# Uploading chunk 480/1145...
# Uploading chunk 481/1145...
# Uploading chunk 482/1145...
# Uploading chunk 483/1145...
# Uploading chunk 484/1145...
# Uploading chunk 485/1145...
# Uploading chunk 486/1145...
# Uploading chunk 487/1145...
# Uploading chunk 488/1145...
# Uploading chunk 489/1145...
# Uploading chunk 490/1145...
# Uploading chunk 491/1145...
# Uploading chunk 492/1145...
# Uploading chunk 493/1145...
# Uploading chunk 494/1145...
# Uploading chunk 495/1145...
# Uploading chunk 496/1145...
# Uploading chunk 497/1145...
# Uploading chunk 498/1145...
# Uploading chunk 499/1145...
# Uploading chunk 500/1145...
# Uploading chunk 501/1145...
# Uploading chunk 502/1145...
# Uploading chunk 503/1145...
# Uploading chunk 504/1145...
# Uploading chunk 505/1145...
# Uploading chunk 506/1145...
# Uploading chunk 507/1145...
# Uploading chunk 508/1145...
# Uploading chunk 509/1145...
# Uploading chunk 510/1145...
# Uploading chunk 511/1145...
# Uploading chunk 512/1145...
# Uploading chunk 513/1145...
# Uploading chunk 514/1145...
# Uploading chunk 515/1145...
# Uploading chunk 516/1145...
# Uploading chunk 517/1145...
# Uploading chunk 518/1145...
# Uploading chunk 519/1145...
# Uploading chunk 520/1145...
# Uploading chunk 521/1145...
# Uploading chunk 522/1145...
# Uploading chunk 523/1145...
# Uploading chunk 524/1145...
# Uploading chunk 525/1145...
# Uploading chunk 526/1145...
# Uploading chunk 527/1145...
# Uploading chunk 528/1145...
# Uploading chunk 529/1145...
# Uploading chunk 530/1145...
# Uploading chunk 531/1145...
# Uploading chunk 532/1145...
# Uploading chunk 533/1145...
# Uploading chunk 534/1145...
# Uploading chunk 535/1145...
# Uploading chunk 536/1145...
# Uploading chunk 537/1145...
# Uploading chunk 538/1145...
# Uploading chunk 539/1145...
# Uploading chunk 540/1145...
# Uploading chunk 541/1145...
# Uploading chunk 542/1145...
# Uploading chunk 543/1145...
# Uploading chunk 544/1145...
# Uploading chunk 545/1145...
# Uploading chunk 546/1145...
# Uploading chunk 547/1145...
# Uploading chunk 548/1145...
# Uploading chunk 549/1145...
# Uploading chunk 550/1145...
# Uploading chunk 551/1145...
# Uploading chunk 552/1145...
# Uploading chunk 553/1145...
# Uploading chunk 554/1145...
# Uploading chunk 555/1145...
# Uploading chunk 556/1145...
# Uploading chunk 557/1145...
# Uploading chunk 558/1145...
# Uploading chunk 559/1145...
# Uploading chunk 560/1145...
# Uploading chunk 561/1145...
# Uploading chunk 562/1145...
# Uploading chunk 563/1145...
# Uploading chunk 564/1145...
# Uploading chunk 565/1145...
# Uploading chunk 566/1145...
# Uploading chunk 567/1145...
# Uploading chunk 568/1145...
# Uploading chunk 569/1145...
# Uploading chunk 570/1145...
# Uploading chunk 571/1145...
# Uploading chunk 572/1145...
# Uploading chunk 573/1145...
# Uploading chunk 574/1145...
# Uploading chunk 575/1145...
# Uploading chunk 576/1145...
# Uploading chunk 577/1145...
# Uploading chunk 578/1145...
# Uploading chunk 579/1145...
# Uploading chunk 580/1145...
# Uploading chunk 581/1145...
# Uploading chunk 582/1145...
# Uploading chunk 583/1145...
# Uploading chunk 584/1145...
# Uploading chunk 585/1145...
# Uploading chunk 586/1145...
# Uploading chunk 587/1145...
# Uploading chunk 588/1145...
# Uploading chunk 589/1145...
# Uploading chunk 590/1145...
# Uploading chunk 591/1145...
# Uploading chunk 592/1145...
# Uploading chunk 593/1145...
# Uploading chunk 594/1145...
# Uploading chunk 595/1145...
# Uploading chunk 596/1145...
# Uploading chunk 597/1145...
# Uploading chunk 598/1145...
# Uploading chunk 599/1145...
# Uploading chunk 600/1145...
# Uploading chunk 601/1145...
# Uploading chunk 602/1145...
# Uploading chunk 603/1145...
# Uploading chunk 604/1145...
# Uploading chunk 605/1145...
# Uploading chunk 606/1145...
# Uploading chunk 607/1145...
# Uploading chunk 608/1145...
# Uploading chunk 609/1145...
# Uploading chunk 610/1145...
# Uploading chunk 611/1145...
# Uploading chunk 612/1145...
# Uploading chunk 613/1145...
# Uploading chunk 614/1145...
# Uploading chunk 615/1145...
# Uploading chunk 616/1145...
# Uploading chunk 617/1145...
# Uploading chunk 618/1145...
# Uploading chunk 619/1145...
# Uploading chunk 620/1145...
# Uploading chunk 621/1145...
# Uploading chunk 622/1145...
# Uploading chunk 623/1145...
# Uploading chunk 624/1145...
# Uploading chunk 625/1145...
# Uploading chunk 626/1145...
# Uploading chunk 627/1145...
# Uploading chunk 628/1145...
# Uploading chunk 629/1145...
# Uploading chunk 630/1145...
# Uploading chunk 631/1145...
# Uploading chunk 632/1145...
# Uploading chunk 633/1145...
# Uploading chunk 634/1145...
# Uploading chunk 635/1145...
# Uploading chunk 636/1145...
# Uploading chunk 637/1145...
# Uploading chunk 638/1145...
# Uploading chunk 639/1145...
# Uploading chunk 640/1145...
# Uploading chunk 641/1145...
# Uploading chunk 642/1145...
# Uploading chunk 643/1145...
# Uploading chunk 644/1145...
# Uploading chunk 645/1145...
# Uploading chunk 646/1145...
# Uploading chunk 647/1145...
# Uploading chunk 648/1145...
# Uploading chunk 649/1145...
# Uploading chunk 650/1145...
# Uploading chunk 651/1145...
# Uploading chunk 652/1145...
# Uploading chunk 653/1145...
# Uploading chunk 654/1145...
# Uploading chunk 655/1145...
# Uploading chunk 656/1145...
# Uploading chunk 657/1145...
# Uploading chunk 658/1145...
# Uploading chunk 659/1145...
# Uploading chunk 660/1145...
# Uploading chunk 661/1145...
# Uploading chunk 662/1145...
# Uploading chunk 663/1145...
# Uploading chunk 664/1145...
# Uploading chunk 665/1145...
# Uploading chunk 666/1145...
# Uploading chunk 667/1145...
# Uploading chunk 668/1145...
# Uploading chunk 669/1145...
# Uploading chunk 670/1145...
# Uploading chunk 671/1145...
# Uploading chunk 672/1145...
# Uploading chunk 673/1145...
# Uploading chunk 674/1145...
# Uploading chunk 675/1145...
# Uploading chunk 676/1145...
# Uploading chunk 677/1145...
# Uploading chunk 678/1145...
# Uploading chunk 679/1145...
# Uploading chunk 680/1145...
# Uploading chunk 681/1145...
# Uploading chunk 682/1145...
# Uploading chunk 683/1145...
# Uploading chunk 684/1145...
# Uploading chunk 685/1145...
# Uploading chunk 686/1145...
# Uploading chunk 687/1145...
# Uploading chunk 688/1145...
# Uploading chunk 689/1145...
# Uploading chunk 690/1145...
# Uploading chunk 691/1145...
# Uploading chunk 692/1145...
# Uploading chunk 693/1145...
# Uploading chunk 694/1145...
# Uploading chunk 695/1145...
# Uploading chunk 696/1145...
# Uploading chunk 697/1145...
# Uploading chunk 698/1145...
# Uploading chunk 699/1145...
# Uploading chunk 700/1145...
# Uploading chunk 701/1145...
# Uploading chunk 702/1145...
# Uploading chunk 703/1145...
# Uploading chunk 704/1145...
# Uploading chunk 705/1145...
# Uploading chunk 706/1145...
# Uploading chunk 707/1145...
# Uploading chunk 708/1145...
# Uploading chunk 709/1145...
# Uploading chunk 710/1145...
# Uploading chunk 711/1145...
# Uploading chunk 712/1145...
# Uploading chunk 713/1145...
# Uploading chunk 714/1145...
# Uploading chunk 715/1145...
# Uploading chunk 716/1145...
# Uploading chunk 717/1145...
# Uploading chunk 718/1145...
# Uploading chunk 719/1145...
# Uploading chunk 720/1145...
# Uploading chunk 721/1145...
# Uploading chunk 722/1145...
# Uploading chunk 723/1145...
# Uploading chunk 724/1145...
# Uploading chunk 725/1145...
# Uploading chunk 726/1145...
# Uploading chunk 727/1145...
# Uploading chunk 728/1145...
# Uploading chunk 729/1145...
# Uploading chunk 730/1145...
# Uploading chunk 731/1145...
# Uploading chunk 732/1145...
# Uploading chunk 733/1145...
# Uploading chunk 734/1145...
# Uploading chunk 735/1145...
# Uploading chunk 736/1145...
# Uploading chunk 737/1145...
# Uploading chunk 738/1145...
# Uploading chunk 739/1145...
# Uploading chunk 740/1145...
# Uploading chunk 741/1145...
# Uploading chunk 742/1145...
# Uploading chunk 743/1145...
# Uploading chunk 744/1145...
# Uploading chunk 745/1145...
# Uploading chunk 746/1145...
# Uploading chunk 747/1145...
# Uploading chunk 748/1145...
# Uploading chunk 749/1145...
# Uploading chunk 750/1145...
# Uploading chunk 751/1145...
# Uploading chunk 752/1145...
# Uploading chunk 753/1145...
# Uploading chunk 754/1145...
# Uploading chunk 755/1145...
# Uploading chunk 756/1145...
# Uploading chunk 757/1145...
# Uploading chunk 758/1145...
# Uploading chunk 759/1145...
# Uploading chunk 760/1145...
# Uploading chunk 761/1145...
# Uploading chunk 762/1145...
# Uploading chunk 763/1145...
# Uploading chunk 764/1145...
# Uploading chunk 765/1145...
# Uploading chunk 766/1145...
# Uploading chunk 767/1145...
# Uploading chunk 768/1145...
# Uploading chunk 769/1145...
# Uploading chunk 770/1145...
# Uploading chunk 771/1145...
# Uploading chunk 772/1145...
# Uploading chunk 773/1145...
# Uploading chunk 774/1145...
# Uploading chunk 775/1145...
# Uploading chunk 776/1145...
# Uploading chunk 777/1145...
# Uploading chunk 778/1145...
# Uploading chunk 779/1145...
# Uploading chunk 780/1145...
# Uploading chunk 781/1145...
# Uploading chunk 782/1145...
# Uploading chunk 783/1145...
# Uploading chunk 784/1145...
# Uploading chunk 785/1145...
# Uploading chunk 786/1145...
# Uploading chunk 787/1145...
# Uploading chunk 788/1145...
# Uploading chunk 789/1145...
# Uploading chunk 790/1145...
# Uploading chunk 791/1145...
# Uploading chunk 792/1145...
# Uploading chunk 793/1145...
# Uploading chunk 794/1145...
# Uploading chunk 795/1145...
# Uploading chunk 796/1145...
# Uploading chunk 797/1145...
# Uploading chunk 798/1145...
# Uploading chunk 799/1145...
# Uploading chunk 800/1145...
# Uploading chunk 801/1145...
# Uploading chunk 802/1145...
# Uploading chunk 803/1145...
# Uploading chunk 804/1145...
# Uploading chunk 805/1145...
# Uploading chunk 806/1145...
# Uploading chunk 807/1145...
# Uploading chunk 808/1145...
# Uploading chunk 809/1145...
# Uploading chunk 810/1145...
# Uploading chunk 811/1145...
# Uploading chunk 812/1145...
# Uploading chunk 813/1145...
# Uploading chunk 814/1145...
# Uploading chunk 815/1145...
# Uploading chunk 816/1145...
# Uploading chunk 817/1145...
# Uploading chunk 818/1145...
# Uploading chunk 819/1145...
# Uploading chunk 820/1145...
# Uploading chunk 821/1145...
# Uploading chunk 822/1145...
# Uploading chunk 823/1145...
# Uploading chunk 824/1145...
# Uploading chunk 825/1145...
# Uploading chunk 826/1145...
# Uploading chunk 827/1145...
# Uploading chunk 828/1145...
# Uploading chunk 829/1145...
# Uploading chunk 830/1145...
# Uploading chunk 831/1145...
# Uploading chunk 832/1145...
# Uploading chunk 833/1145...
# Uploading chunk 834/1145...
# Uploading chunk 835/1145...
# Uploading chunk 836/1145...
# Uploading chunk 837/1145...
# Uploading chunk 838/1145...
# Uploading chunk 839/1145...
# Uploading chunk 840/1145...
# Uploading chunk 841/1145...
# Uploading chunk 842/1145...
# Uploading chunk 843/1145...
# Uploading chunk 844/1145...
# Uploading chunk 845/1145...
# Uploading chunk 846/1145...
# Uploading chunk 847/1145...
# Uploading chunk 848/1145...
# Uploading chunk 849/1145...
# Uploading chunk 850/1145...
# Uploading chunk 851/1145...
# Uploading chunk 852/1145...
# Uploading chunk 853/1145...
# Uploading chunk 854/1145...
# Uploading chunk 855/1145...
# Uploading chunk 856/1145...
# Uploading chunk 857/1145...
# Uploading chunk 858/1145...
# Uploading chunk 859/1145...
# Uploading chunk 860/1145...
# Uploading chunk 861/1145...
# Uploading chunk 862/1145...
# Uploading chunk 863/1145...
# Uploading chunk 864/1145...
# Uploading chunk 865/1145...
# Uploading chunk 866/1145...
# Uploading chunk 867/1145...
# Uploading chunk 868/1145...
# Uploading chunk 869/1145...
# Uploading chunk 870/1145...
# Uploading chunk 871/1145...
# Uploading chunk 872/1145...
# Uploading chunk 873/1145...
# Uploading chunk 874/1145...
# Uploading chunk 875/1145...
# Uploading chunk 876/1145...
# Uploading chunk 877/1145...
# Uploading chunk 878/1145...
# Uploading chunk 879/1145...
# Uploading chunk 880/1145...
# Uploading chunk 881/1145...
# Uploading chunk 882/1145...
# Uploading chunk 883/1145...
# Uploading chunk 884/1145...
# Uploading chunk 885/1145...
# Uploading chunk 886/1145...
# Uploading chunk 887/1145...
# Uploading chunk 888/1145...
# Uploading chunk 889/1145...
# Uploading chunk 890/1145...
# Uploading chunk 891/1145...
# Uploading chunk 892/1145...
# Uploading chunk 893/1145...
# Uploading chunk 894/1145...
# Uploading chunk 895/1145...
# Uploading chunk 896/1145...
# Uploading chunk 897/1145...
# Uploading chunk 898/1145...
# Uploading chunk 899/1145...
# Uploading chunk 900/1145...
# Uploading chunk 901/1145...
# Uploading chunk 902/1145...
# Uploading chunk 903/1145...
# Uploading chunk 904/1145...
# Uploading chunk 905/1145...
# Uploading chunk 906/1145...
# Uploading chunk 907/1145...
# Uploading chunk 908/1145...
# Uploading chunk 909/1145...
# Uploading chunk 910/1145...
# Uploading chunk 911/1145...
# Uploading chunk 912/1145...
# Uploading chunk 913/1145...
# Uploading chunk 914/1145...
# Uploading chunk 915/1145...
# Uploading chunk 916/1145...
# Uploading chunk 917/1145...
# Uploading chunk 918/1145...
# Uploading chunk 919/1145...
# Uploading chunk 920/1145...
# Uploading chunk 921/1145...
# Uploading chunk 922/1145...
# Uploading chunk 923/1145...
# Uploading chunk 924/1145...
# Uploading chunk 925/1145...
# Uploading chunk 926/1145...
# Uploading chunk 927/1145...
# Uploading chunk 928/1145...
# Uploading chunk 929/1145...
# Uploading chunk 930/1145...
# Uploading chunk 931/1145...
# Uploading chunk 932/1145...
# Uploading chunk 933/1145...
# Uploading chunk 934/1145...
# Uploading chunk 935/1145...
# Uploading chunk 936/1145...
# Uploading chunk 937/1145...
# Uploading chunk 938/1145...
# Uploading chunk 939/1145...
# Uploading chunk 940/1145...
# Uploading chunk 941/1145...
# Uploading chunk 942/1145...
# Uploading chunk 943/1145...
# Uploading chunk 944/1145...
# Uploading chunk 945/1145...
# Uploading chunk 946/1145...
# Uploading chunk 947/1145...
# Uploading chunk 948/1145...
# Uploading chunk 949/1145...
# Uploading chunk 950/1145...
# Uploading chunk 951/1145...
# Uploading chunk 952/1145...
# Uploading chunk 953/1145...
# Uploading chunk 954/1145...
# Uploading chunk 955/1145...
# Uploading chunk 956/1145...
# Uploading chunk 957/1145...
# Uploading chunk 958/1145...
# Uploading chunk 959/1145...
# Uploading chunk 960/1145...
# Uploading chunk 961/1145...
# Uploading chunk 962/1145...
# Uploading chunk 963/1145...
# Uploading chunk 964/1145...
# Uploading chunk 965/1145...
# Uploading chunk 966/1145...
# Uploading chunk 967/1145...
# Uploading chunk 968/1145...
# Uploading chunk 969/1145...
# Uploading chunk 970/1145...
# Uploading chunk 971/1145...
# Uploading chunk 972/1145...
# Uploading chunk 973/1145...
# Uploading chunk 974/1145...
# Uploading chunk 975/1145...
# Uploading chunk 976/1145...
# Uploading chunk 977/1145...
# Uploading chunk 978/1145...
# Uploading chunk 979/1145...
# Uploading chunk 980/1145...
# Uploading chunk 981/1145...
# Uploading chunk 982/1145...
# Uploading chunk 983/1145...
# Uploading chunk 984/1145...
# Uploading chunk 985/1145...
# Uploading chunk 986/1145...
# Uploading chunk 987/1145...
# Uploading chunk 988/1145...
# Uploading chunk 989/1145...
# Uploading chunk 990/1145...
# Uploading chunk 991/1145...
# Uploading chunk 992/1145...
# Uploading chunk 993/1145...
# Uploading chunk 994/1145...
# Uploading chunk 995/1145...
# Uploading chunk 996/1145...
# Uploading chunk 997/1145...
# Uploading chunk 998/1145...
# Uploading chunk 999/1145...
# Uploading chunk 1000/1145...
# Uploading chunk 1001/1145...
# Uploading chunk 1002/1145...
# Uploading chunk 1003/1145...
# Uploading chunk 1004/1145...
# Uploading chunk 1005/1145...
# Uploading chunk 1006/1145...
# Uploading chunk 1007/1145...
# Uploading chunk 1008/1145...
# Uploading chunk 1009/1145...
# Uploading chunk 1010/1145...
# Uploading chunk 1011/1145...
# Uploading chunk 1012/1145...
# Uploading chunk 1013/1145...
# Uploading chunk 1014/1145...
# Uploading chunk 1015/1145...
# Uploading chunk 1016/1145...
# Uploading chunk 1017/1145...
# Uploading chunk 1018/1145...
# Uploading chunk 1019/1145...
# Uploading chunk 1020/1145...
# Uploading chunk 1021/1145...
# Uploading chunk 1022/1145...
# Uploading chunk 1023/1145...
# Uploading chunk 1024/1145...
# Uploading chunk 1025/1145...
# Uploading chunk 1026/1145...
# Uploading chunk 1027/1145...
# Uploading chunk 1028/1145...
# Uploading chunk 1029/1145...
# Uploading chunk 1030/1145...
# Uploading chunk 1031/1145...
# Uploading chunk 1032/1145...
# Uploading chunk 1033/1145...
# Uploading chunk 1034/1145...
# Uploading chunk 1035/1145...
# Uploading chunk 1036/1145...
# Uploading chunk 1037/1145...
# Uploading chunk 1038/1145...
# Uploading chunk 1039/1145...
# Uploading chunk 1040/1145...
# Uploading chunk 1041/1145...
# Uploading chunk 1042/1145...
# Uploading chunk 1043/1145...
# Uploading chunk 1044/1145...
# Uploading chunk 1045/1145...
# Uploading chunk 1046/1145...
# Uploading chunk 1047/1145...
# Uploading chunk 1048/1145...
# Uploading chunk 1049/1145...
# Uploading chunk 1050/1145...
# Uploading chunk 1051/1145...
# Uploading chunk 1052/1145...
# Uploading chunk 1053/1145...
# Uploading chunk 1054/1145...
# Uploading chunk 1055/1145...
# Uploading chunk 1056/1145...
# Uploading chunk 1057/1145...
# Uploading chunk 1058/1145...
# Uploading chunk 1059/1145...
# Uploading chunk 1060/1145...
# Uploading chunk 1061/1145...
# Uploading chunk 1062/1145...
# Uploading chunk 1063/1145...
# Uploading chunk 1064/1145...
# Uploading chunk 1065/1145...
# Uploading chunk 1066/1145...
# Uploading chunk 1067/1145...
# Uploading chunk 1068/1145...
# Uploading chunk 1069/1145...
# Uploading chunk 1070/1145...
# Uploading chunk 1071/1145...
# Uploading chunk 1072/1145...
# Uploading chunk 1073/1145...
# Uploading chunk 1074/1145...
# Uploading chunk 1075/1145...
# Uploading chunk 1076/1145...
# Uploading chunk 1077/1145...
# Uploading chunk 1078/1145...
# Uploading chunk 1079/1145...
# Uploading chunk 1080/1145...
# Uploading chunk 1081/1145...
# Uploading chunk 1082/1145...
# Uploading chunk 1083/1145...
# Uploading chunk 1084/1145...
# Uploading chunk 1085/1145...
# Uploading chunk 1086/1145...
# Uploading chunk 1087/1145...
# Uploading chunk 1088/1145...
# Uploading chunk 1089/1145...
# Uploading chunk 1090/1145...
# Uploading chunk 1091/1145...
# Uploading chunk 1092/1145...
# Uploading chunk 1093/1145...
# Uploading chunk 1094/1145...
# Uploading chunk 1095/1145...
# Uploading chunk 1096/1145...
# Uploading chunk 1097/1145...
# Uploading chunk 1098/1145...
# Uploading chunk 1099/1145...
# Uploading chunk 1100/1145...
# Uploading chunk 1101/1145...
# Uploading chunk 1102/1145...
# Uploading chunk 1103/1145...
# Uploading chunk 1104/1145...
# Uploading chunk 1105/1145...
# Uploading chunk 1106/1145...
# Uploading chunk 1107/1145...
# Uploading chunk 1108/1145...
# Uploading chunk 1109/1145...
# Uploading chunk 1110/1145...
# Uploading chunk 1111/1145...
# Uploading chunk 1112/1145...
# Uploading chunk 1113/1145...
# Uploading chunk 1114/1145...
# Uploading chunk 1115/1145...
# Uploading chunk 1116/1145...
# Uploading chunk 1117/1145...
# Uploading chunk 1118/1145...
# Uploading chunk 1119/1145...
# Uploading chunk 1120/1145...
# Uploading chunk 1121/1145...
# Uploading chunk 1122/1145...
# Uploading chunk 1123/1145...
# Uploading chunk 1124/1145...
# Uploading chunk 1125/1145...
# Uploading chunk 1126/1145...
# Uploading chunk 1127/1145...
# Uploading chunk 1128/1145...
# Uploading chunk 1129/1145...
# Uploading chunk 1130/1145...
# Uploading chunk 1131/1145...
# Uploading chunk 1132/1145...
# Uploading chunk 1133/1145...
# Uploading chunk 1134/1145...
# Uploading chunk 1135/1145...
# Uploading chunk 1136/1145...
# Uploading chunk 1137/1145...
# Uploading chunk 1138/1145...
# Uploading chunk 1139/1145...
# Uploading chunk 1140/1145...
# Uploading chunk 1141/1145...
# Uploading chunk 1142/1145...
# Uploading chunk 1143/1145...
# Uploading chunk 1144/1145...
# Uploading chunk 1145/1145...
# Upload complete.

# %% [markdown]
# ## EBR

# %% [markdown]
# Enkel søgning

# %%
# Define the API endpoint URL
url = "https://services.datafordeler.dk/DAR/DAR_BFE_Public/1/rest/adresseTilEnhedBfe?username=ANLVUSSNAP&password=Essvietcc567!&Format=JSON&adresseId=0a3f509e-d15b-32b8-e044-0003ba298018"

try:
    # Make the API call and get the JSON response
    response = requests.get(url)
    response.raise_for_status()  # Check for any errors in the API call

    # Print the JSON response
    print(response.json())

except requests.exceptions.RequestException as e:
    print("Error making the API call:", e)
except ValueError as ve:
    print("Error processing JSON response:", ve)
# Out:
# []

# %% [markdown]
# Load pkl

# %%
import pandas as pd

# Load pickle file into dataframe
path = r"C:\Users\viet-intel\boligpriser\data\output\DAR.pkl"

DAR = pd.read_pickle(path)

print(list(DAR.columns))
print(len(DAR))

# %% [markdown]
# Lav ny dataframe med id og tom bfe kolonne

# %%
# select the columns id
bfe_id = DAR[['id_lokalId']]

# adding empty column bfe to the dataframe
bfe_id['BFE'] = ""

display(bfe_id.head())
len(bfe_id)

# %% [markdown]
# Finder tilsvarende BFE nummer til hver adresse

# %%
import requests
import pandas as pd

def get_data_from_api(adresse_ids):
    url = f"https://services.datafordeler.dk/EBR/Ejendomsbeliggenhed/1/rest/BFEnrAdresse?Adresseid={adresse_ids}&username=ANLVUSSNAP&password=Essvietcc567!"
    
    try:
        response = requests.get(url)
        response.raise_for_status()
        return response.json()
    except requests.exceptions.RequestException as e:
        print("Error making the API call:", e)
        return None
    except ValueError as ve:
        print("Error processing JSON response:", ve)
        return None

def chunker(seq, size):
    # Function to divide the list into chunks of specified size
    return (seq[pos:pos + size] for pos in range(0, len(seq), size))

# Load the dataframe
# region_hovedstad_df = pd.read_csv('your_data.csv')

# Select the first 1000 rows of the dataframe
adresse_ids = DAR['id_lokalId'].iloc[:100000].str.strip().tolist()

df_list = []
for chunk in chunker(adresse_ids, 20):
    adresse_ids_str = '|'.join(chunk)
    response_data = get_data_from_api(adresse_ids_str)
    if response_data and 'features' in response_data:
        for feature in response_data['features']:
            properties = feature['properties']
            df_list.append(properties)

# Convert the list of dictionaries to a DataFrame
bfe_df = pd.DataFrame(df_list)

# Display the first few rows of the DataFrame
display(bfe_df.head())
print(len(bfe_df))

# save the dataframe to a pickle file
bfe_df.to_pickle(r"C:\Users\viet-intel\boligpriser\data\output\EBR\bfe.pkl")

# %%
import pandas as pd
import os

# Get a list of all .pkl files in the directory
dir_path = r'C:\Users\viet-intel\boligpriser\data\output\EBR'
file_list = [f for f in os.listdir(dir_path) if f.endswith('.pkl')]

# Initialize an empty list that will be used to store the data frames
df_list = []

# Loop through the list of files and read each one into a pandas data frame
for file in file_list:
    file_path = os.path.join(dir_path, file)
    df = pd.read_pickle(file_path)  # load pickle file
    df_list.append(df)

# Concatenate all of the data frames into one
EBR_df = pd.concat(df_list, ignore_index=True)

# Print length of the combined DataFrame
print(f'Length of combined DataFrame: {len(EBR_df)}')
# Out:
# Length of combined DataFrame: 179463

# %%
EBR_df.head()
# Out:
#                                        id_namespace  \
# 0  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 1  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 2  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 3  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 4  http://data.gov.dk/Ejendomsbeliggenhedsregistret
#
#                              id_lokalId bestemtFastEjendomBFENr  \
# 0  fea8a5da-38ae-4504-afb6-a605d566e803                  173846
# 1  073e294d-7685-40ec-a802-87b2820983da                  172353
# 2  a4cdd92e-2fa0-4eb7-a599-68644e841806                  172355
# 3  2486fef4-13f9-4ee3-b78f-9785ea10d55d                  172356
# 4  2f57e964-cc7a-474c-a162-69161816ff50                  172357
#
#     Ejendomstype  adresseManueltAngivet ESDHReferenceAdresse  \
# 0  Ejerlejlighed                  False                 None
# 1  Ejerlejlighed                  False                 None
# 2  Ejerlejlighed                  False                 None
# 3  Ejerlejlighed                  False                 None
# 4  Ejerlejlighed                  False                 None
#
#   ESDHReferenceKommune  kommuneManueltAngivet kommuneinddelingKommunekode  \
# 0                 None                  False                        0101
# 1                 None                  False                        0101
# 2                 None                  False                        0101
# 3                 None                  False                        0101
# 4                 None                  False                        0101
#
#   betegnelse  ...    status forretningshaendelse forretningsomraade  \
# 0       None  ...  gældende    konverteretFraESR           52.20.05
# 1       None  ...  gældende    konverteretFraESR           52.20.05
# 2       None  ...  gældende    konverteretFraESR           52.20.05
# 3       None  ...  gældende    konverteretFraESR           52.20.05
# 4       None  ...  gældende    konverteretFraESR           52.20.05
#
#    forretningsproces                       virkningFra virkningTil  \
# 0  konverteretFraESR  0001-01-01T15:00:00.000000+00:50        None
# 1  konverteretFraESR  0001-01-01T15:00:00.000000+00:50        None
# 2  konverteretFraESR  0001-01-01T15:00:00.000000+00:50        None
# 3  konverteretFraESR  0001-01-01T15:00:00.000000+00:50        None
# 4  konverteretFraESR  0001-01-01T15:00:00.000000+00:50        None
#
#     virkningsaktoer                   registreringFra registreringTil  \
# 0  Geodatastyrelsen  2019-04-28T13:21:47.972423+02:00            None
# 1  Geodatastyrelsen  2019-04-28T13:21:46.321174+02:00            None
# 2  Geodatastyrelsen  2019-04-28T13:21:46.321737+02:00            None
# 3  Geodatastyrelsen  2019-04-28T13:21:46.322216+02:00            None
# 4  Geodatastyrelsen  2019-04-28T13:21:46.322340+02:00            None
#
#             registreringsaktoer
# 0  Ejendomsbeliggenhedsregister
# 1  Ejendomsbeliggenhedsregister
# 2  Ejendomsbeliggenhedsregister
# 3  Ejendomsbeliggenhedsregister
# 4  Ejendomsbeliggenhedsregister
#
# [5 rows x 22 columns]

# %% [markdown]
# Load to my SQL

# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine, types
from math import ceil

# MySQL connection setup
username = 'root'
password = '1234'
host = 'localhost'
database = 'bolig'

engine_str = f"mysql+mysqlconnector://{username}:{password}@{host}/{database}"
engine = create_engine(engine_str)

# Fetching the dtypes for each column
dtype_dict = EBR_df.dtypes.map(lambda x: types.TEXT 
                                  if x == "object" 
                                  else types.Float(precision=3, asdecimal=True) 
                                  if x == "float" 
                                  else types.Integer()).to_dict()

# Create table if doesn't exist
EBR_df[:0].to_sql('ebr', con=engine, if_exists='replace', dtype=dtype_dict)

# Upload data in chunks
n = 1000  # chunk row size
total_chunks = ceil(len(EBR_df) / n)

for i in range(total_chunks):
    print(f'Uploading chunk {i+1}/{total_chunks}...')
    EBR_df[i*n:(i+1)*n].to_sql('ebr', con=engine, if_exists='append', dtype=dtype_dict)
    
print("Upload complete.")
# Out:
# Uploading chunk 1/180...
# Uploading chunk 2/180...
# Uploading chunk 3/180...
# Uploading chunk 4/180...
# Uploading chunk 5/180...
# Uploading chunk 6/180...
# Uploading chunk 7/180...
# Uploading chunk 8/180...
# Uploading chunk 9/180...
# Uploading chunk 10/180...
# Uploading chunk 11/180...
# Uploading chunk 12/180...
# Uploading chunk 13/180...
# Uploading chunk 14/180...
# Uploading chunk 15/180...
# Uploading chunk 16/180...
# Uploading chunk 17/180...
# Uploading chunk 18/180...
# Uploading chunk 19/180...
# Uploading chunk 20/180...
# Uploading chunk 21/180...
# Uploading chunk 22/180...
# Uploading chunk 23/180...
# Uploading chunk 24/180...
# Uploading chunk 25/180...
# Uploading chunk 26/180...
# Uploading chunk 27/180...
# Uploading chunk 28/180...
# Uploading chunk 29/180...
# Uploading chunk 30/180...
# Uploading chunk 31/180...
# Uploading chunk 32/180...
# Uploading chunk 33/180...
# Uploading chunk 34/180...
# Uploading chunk 35/180...
# Uploading chunk 36/180...
# Uploading chunk 37/180...
# Uploading chunk 38/180...
# Uploading chunk 39/180...
# Uploading chunk 40/180...
# Uploading chunk 41/180...
# Uploading chunk 42/180...
# Uploading chunk 43/180...
# Uploading chunk 44/180...
# Uploading chunk 45/180...
# Uploading chunk 46/180...
# Uploading chunk 47/180...
# Uploading chunk 48/180...
# Uploading chunk 49/180...
# Uploading chunk 50/180...
# Uploading chunk 51/180...
# Uploading chunk 52/180...
# Uploading chunk 53/180...
# Uploading chunk 54/180...
# Uploading chunk 55/180...
# Uploading chunk 56/180...
# Uploading chunk 57/180...
# Uploading chunk 58/180...
# Uploading chunk 59/180...
# Uploading chunk 60/180...
# Uploading chunk 61/180...
# Uploading chunk 62/180...
# Uploading chunk 63/180...
# Uploading chunk 64/180...
# Uploading chunk 65/180...
# Uploading chunk 66/180...
# Uploading chunk 67/180...
# Uploading chunk 68/180...
# Uploading chunk 69/180...
# Uploading chunk 70/180...
# Uploading chunk 71/180...
# Uploading chunk 72/180...
# Uploading chunk 73/180...
# Uploading chunk 74/180...
# Uploading chunk 75/180...
# Uploading chunk 76/180...
# Uploading chunk 77/180...
# Uploading chunk 78/180...
# Uploading chunk 79/180...
# Uploading chunk 80/180...
# Uploading chunk 81/180...
# Uploading chunk 82/180...
# Uploading chunk 83/180...
# Uploading chunk 84/180...
# Uploading chunk 85/180...
# Uploading chunk 86/180...
# Uploading chunk 87/180...
# Uploading chunk 88/180...
# Uploading chunk 89/180...
# Uploading chunk 90/180...
# Uploading chunk 91/180...
# Uploading chunk 92/180...
# Uploading chunk 93/180...
# Uploading chunk 94/180...
# Uploading chunk 95/180...
# Uploading chunk 96/180...
# Uploading chunk 97/180...
# Uploading chunk 98/180...
# Uploading chunk 99/180...
# Uploading chunk 100/180...
# Uploading chunk 101/180...
# Uploading chunk 102/180...
# Uploading chunk 103/180...
# Uploading chunk 104/180...
# Uploading chunk 105/180...
# Uploading chunk 106/180...
# Uploading chunk 107/180...
# Uploading chunk 108/180...
# Uploading chunk 109/180...
# Uploading chunk 110/180...
# Uploading chunk 111/180...
# Uploading chunk 112/180...
# Uploading chunk 113/180...
# Uploading chunk 114/180...
# Uploading chunk 115/180...
# Uploading chunk 116/180...
# Uploading chunk 117/180...
# Uploading chunk 118/180...
# Uploading chunk 119/180...
# Uploading chunk 120/180...
# Uploading chunk 121/180...
# Uploading chunk 122/180...
# Uploading chunk 123/180...
# Uploading chunk 124/180...
# Uploading chunk 125/180...
# Uploading chunk 126/180...
# Uploading chunk 127/180...
# Uploading chunk 128/180...
# Uploading chunk 129/180...
# Uploading chunk 130/180...
# Uploading chunk 131/180...
# Uploading chunk 132/180...
# Uploading chunk 133/180...
# Uploading chunk 134/180...
# Uploading chunk 135/180...
# Uploading chunk 136/180...
# Uploading chunk 137/180...
# Uploading chunk 138/180...
# Uploading chunk 139/180...
# Uploading chunk 140/180...
# Uploading chunk 141/180...
# Uploading chunk 142/180...
# Uploading chunk 143/180...
# Uploading chunk 144/180...
# Uploading chunk 145/180...
# Uploading chunk 146/180...
# Uploading chunk 147/180...
# Uploading chunk 148/180...
# Uploading chunk 149/180...
# Uploading chunk 150/180...
# Uploading chunk 151/180...
# Uploading chunk 152/180...
# Uploading chunk 153/180...
# Uploading chunk 154/180...
# Uploading chunk 155/180...
# Uploading chunk 156/180...
# Uploading chunk 157/180...
# Uploading chunk 158/180...
# Uploading chunk 159/180...
# Uploading chunk 160/180...
# Uploading chunk 161/180...
# Uploading chunk 162/180...
# Uploading chunk 163/180...
# Uploading chunk 164/180...
# Uploading chunk 165/180...
# Uploading chunk 166/180...
# Uploading chunk 167/180...
# Uploading chunk 168/180...
# Uploading chunk 169/180...
# Uploading chunk 170/180...
# Uploading chunk 171/180...
# Uploading chunk 172/180...
# Uploading chunk 173/180...
# Uploading chunk 174/180...
# Uploading chunk 175/180...
# Uploading chunk 176/180...
# Uploading chunk 177/180...
# Uploading chunk 178/180...
# Uploading chunk 179/180...
# Uploading chunk 180/180...
# Upload complete.

# %% [markdown]
# ## Creating sample

# %%
import pandas as pd
from sqlalchemy import create_engine

# MySQL connection setup
username = 'root'
password = '1234'
host = 'localhost'
database = 'bolig'

# Establish a connection to the MySQL database
engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}/{database}')

# SQL query to select all data from the "ebr" table
query = 'SELECT * FROM ebr_sample WHERE ois = false'

# Load the data into a pandas DataFrame
ebrsql_df = pd.read_sql_query(query, engine)

# Close the database connection
engine.dispose()

# print length of dataframe
print(len(ebrsql_df))
# Out:
# 72281

# %%
ebrsql_df.drop(columns=['part'])
# Out:
#        index                                      id_namespace  \
# 0       9564  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 1       9728  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 2      11488  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 3      11729  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 4      14107  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# ...      ...                                               ...
# 72276  89728  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 72277  89729  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 72278  89730  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 72279  89731  http://data.gov.dk/Ejendomsbeliggenhedsregistret
# 72280  89732  http://data.gov.dk/Ejendomsbeliggenhedsregistret
#
#                                  id_lokalId bestemtFastEjendomBFENr  \
# 0      8dd528e4-2551-4c02-852e-8837fbdda1d0                  414573
# 1      fb33c8c8-5bb7-4d4a-8b2f-588a7b69f53a                  500287
# 2      2182e5a2-bc85-47f5-9f42-2801ea068c19                  500181
# 3      c34ceed2-f96f-4b49-a93c-a3f226dfeffb                  173521
# 4      8b8e1f14-c29a-488c-8d86-30ae3b387ccc                  500276
# ...                                     ...                     ...
# 72276  26cfb8b6-8abb-4a0c-8546-35f53ab7eecc                  161991
# 72277  f564f075-8bf9-4065-a8ee-a9a4a55c9524                  119472
# 72278  da11882a-775c-4e19-93db-b079bd66e844                  140542
# 72279  676ecb69-56b8-42a7-8e13-eecf656295ad                  255877
# 72280  d70011aa-e607-43bc-b89e-acc490655f73                  107414
#
#         Ejendomstype  adresseManueltAngivet ESDHReferenceAdresse  \
# 0      Ejerlejlighed                      0                 None
# 1      Ejerlejlighed                      0                 None
# 2      Ejerlejlighed                      0                 None
# 3      Ejerlejlighed                      0                 None
# 4      Ejerlejlighed                      0                 None
# ...              ...                    ...                  ...
# 72276  Ejerlejlighed                      0                 None
# 72277  Ejerlejlighed                      0                 None
# 72278  Ejerlejlighed                      0                 None
# 72279  Ejerlejlighed                      0                 None
# 72280  Ejerlejlighed                      0                 None
#
#       ESDHReferenceKommune  kommuneManueltAngivet kommuneinddelingKommunekode  \
# 0                     None                      0                        0101
# 1                     None                      0                        0147
# 2                     None                      0                        0147
# 3                     None                      0                        0101
# 4                     None                      0                        0147
# ...                    ...                    ...                         ...
# 72276                 None                      0                        0101
# 72277                 None                      0                        0101
# 72278                 None                      0                        0101
# 72279                 None                      0                        0219
# 72280                 None                      0                        0101
#
#        ... forretningshaendelse forretningsomraade  forretningsproces  \
# 0      ...    konverteretFraESR           52.20.05  konverteretFraESR
# 1      ...    konverteretFraESR           52.20.05  konverteretFraESR
# 2      ...    konverteretFraESR           52.20.05  konverteretFraESR
# 3      ...    konverteretFraESR           52.20.05  konverteretFraESR
# 4      ...    konverteretFraESR           52.20.05  konverteretFraESR
# ...    ...                  ...                ...                ...
# 72276  ...    konverteretFraESR           52.20.05  konverteretFraESR
# 72277  ...    konverteretFraESR           52.20.05  konverteretFraESR
# 72278  ...    konverteretFraESR           52.20.05  konverteretFraESR
# 72279  ...    konverteretFraESR           52.20.05  konverteretFraESR
# 72280  ...    konverteretFraESR           52.20.05  konverteretFraESR
#
#                             virkningFra virkningTil   virkningsaktoer  \
# 0      0001-01-01T15:00:00.000000+00:50        None  Geodatastyrelsen
# 1      0001-01-01T15:00:00.000000+00:50        None  Geodatastyrelsen
# 2      0001-01-01T15:00:00.000000+00:50        None  Geodatastyrelsen
# 3      0001-01-01T15:00:00.000000+00:50        None  Geodatastyrelsen
# 4      0001-01-01T15:00:00.000000+00:50        None  Geodatastyrelsen
# ...                                 ...         ...               ...
# 72276  0001-01-01T15:00:00.000000+00:50        None  Geodatastyrelsen
# 72277  0001-01-01T15:00:00.000000+00:50        None  Geodatastyrelsen
# 72278  0001-01-01T15:00:00.000000+00:50        None  Geodatastyrelsen
# 72279  0001-01-01T15:00:00.000000+00:50        None  Geodatastyrelsen
# 72280  0001-01-01T15:00:00.000000+00:50        None  Geodatastyrelsen
#
#                         registreringFra registreringTil  \
# 0      2019-04-28T13:22:51.482668+02:00            None
# 1      2019-04-28T13:22:56.920166+02:00            None
# 2      2019-04-28T13:22:56.596559+02:00            None
# 3      2019-04-28T13:21:47.677911+02:00            None
# 4      2019-04-28T13:22:56.828305+02:00            None
# ...                                 ...             ...
# 72276  2019-04-28T13:21:44.629879+02:00            None
# 72277  2019-04-28T13:21:33.996957+02:00            None
# 72278  2019-04-28T13:21:38.990995+02:00            None
# 72279  2019-04-28T13:22:08.072299+02:00            None
# 72280  2019-04-28T13:21:30.559102+02:00            None
#
#                 registreringsaktoer ois
# 0      Ejendomsbeliggenhedsregister   0
# 1      Ejendomsbeliggenhedsregister   0
# 2      Ejendomsbeliggenhedsregister   0
# 3      Ejendomsbeliggenhedsregister   0
# 4      Ejendomsbeliggenhedsregister   0
# ...                             ...  ..
# 72276  Ejendomsbeliggenhedsregister   0
# 72277  Ejendomsbeliggenhedsregister   0
# 72278  Ejendomsbeliggenhedsregister   0
# 72279  Ejendomsbeliggenhedsregister   0
# 72280  Ejendomsbeliggenhedsregister   0
#
# [72281 rows x 24 columns]

# %%
ebrsql_df['part'] = (ebrsql_df.index % 10) + 1

# %%
ebrsql_df

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sqlalchemy import create_engine

# MySQL connection setup
username = 'root'
password = '1234'
host = 'localhost'
database = 'bolig'

# Establish a connection to the MySQL database
engine = create_engine(f'mysql+pymysql://{username}:{password}@{host}/{database}')

# SQL query to select all data from the "ebr" table
query = 'SELECT * FROM ebr'

# Load the data into a pandas DataFrame
df = pd.read_sql_query(query, engine)

# Close the database connection
engine.dispose()

# Calculate the percentage distribution for each kommuneinddelingKommunekode
percentage_distribution = df['kommuneinddelingKommunekode'].value_counts(normalize=True)

# Split the dataset into two equal parts using stratified sampling
df_part1, df_part2 = train_test_split(
    df,
    test_size=0.5,
    stratify=df['kommuneinddelingKommunekode'],
    random_state=42
)

# Now you have your original dataset "df" and two equal halves "df_part1" and "df_part2"
# with the same percentage distribution for the kommuneinddelingKommunekode column.

# %%
# Shuffle the two parts independently to randomize the order within each group
df_part1_shuffled = df_part1.sample(frac=1, random_state=42).reset_index(drop=True)
df_part2_shuffled = df_part2.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
len(df_part1_shuffled)
# Out:
# 89731

# %%
import pandas as pd
import numpy as np

# Assuming you already have the two equal parts "df_part1_shuffled" and "df_part2_shuffled"
# obtained through the previous steps

# Concatenate the two parts to work with the entire dataset
df_combined = pd.concat([df_part1_shuffled, df_part2_shuffled], ignore_index=True)

# Calculate the total number of rows and the target number of rows for each part (close to 25%)
total_rows = len(df_combined)
target_part_size = int(total_rows * 0.25)

# Create an array of numbers from 1 to 4, where each number appears target_part_size times
part_numbers = np.repeat(np.arange(1, 5), target_part_size)

# Adjust the length of the part_numbers array to match the total number of rows
part_numbers = np.resize(part_numbers, total_rows)

# Randomly shuffle the array to ensure random distribution
np.random.shuffle(part_numbers)

# Assign the part_numbers array as the "part" column to df_combined
df_combined['part'] = part_numbers

# Split df_combined back into the two parts
df_part1_shuffled_with_part = df_combined[df_combined['part'].isin([1, 2])].reset_index(drop=True)
df_part2_shuffled_with_part = df_combined[df_combined['part'].isin([3, 4])].reset_index(drop=True)

# Now, df_part1_shuffled_with_part and df_part2_shuffled_with_part represent the two equal halves
# with the same percentage distribution for the kommuneinddelingKommunekode column,
# both parts are shuffled randomly, and each part has the "part" column with values ranging from 1 to 4
# where each number appears close to 25% of the total rows.

# %%
len(df_part1_shuffled_with_part)
# Out:
# 89733

# %%
import pandas as pd
import mysql.connector
from sqlalchemy import create_engine, types
from math import ceil

# MySQL connection setup
username = 'root'
password = '1234'
host = 'localhost'
database = 'bolig'

engine_str = f"mysql+mysqlconnector://{username}:{password}@{host}/{database}"
engine = create_engine(engine_str)

# Fetching the dtypes for each column
dtype_dict = ebrsql_df.dtypes.map(lambda x: types.TEXT 
                                  if x == "object" 
                                  else types.Float(precision=3, asdecimal=True) 
                                  if x == "float" 
                                  else types.Integer()).to_dict()

# Create table if doesn't exist
ebrsql_df[:0].to_sql('ebr_sample10', con=engine, if_exists='replace', dtype=dtype_dict)

# Upload data in chunks
n = 1000  # chunk row size
total_chunks = ceil(len(ebrsql_df) / n)

for i in range(total_chunks):
    print(f'Uploading chunk {i+1}/{total_chunks}...')
    ebrsql_df[i*n:(i+1)*n].to_sql('ebr_sample10', con=engine, if_exists='append', dtype=dtype_dict)
    
print("Upload complete.")
# Out:
# Uploading chunk 1/73...
# Uploading chunk 2/73...
# Uploading chunk 3/73...
# Uploading chunk 4/73...
# Uploading chunk 5/73...
# Uploading chunk 6/73...
# Uploading chunk 7/73...
# Uploading chunk 8/73...
# Uploading chunk 9/73...
# Uploading chunk 10/73...
# Uploading chunk 11/73...
# Uploading chunk 12/73...
# Uploading chunk 13/73...
# Uploading chunk 14/73...
# Uploading chunk 15/73...
# Uploading chunk 16/73...
# Uploading chunk 17/73...
# Uploading chunk 18/73...
# Uploading chunk 19/73...
# Uploading chunk 20/73...
# Uploading chunk 21/73...
# Uploading chunk 22/73...
# Uploading chunk 23/73...
# Uploading chunk 24/73...
# Uploading chunk 25/73...
# Uploading chunk 26/73...
# Uploading chunk 27/73...
# Uploading chunk 28/73...
# Uploading chunk 29/73...
# Uploading chunk 30/73...
# Uploading chunk 31/73...
# Uploading chunk 32/73...
# Uploading chunk 33/73...
# Uploading chunk 34/73...
# Uploading chunk 35/73...
# Uploading chunk 36/73...
# Uploading chunk 37/73...
# Uploading chunk 38/73...
# Uploading chunk 39/73...
# Uploading chunk 40/73...
# Uploading chunk 41/73...
# Uploading chunk 42/73...
# Uploading chunk 43/73...
# Uploading chunk 44/73...
# Uploading chunk 45/73...
# Uploading chunk 46/73...
# Uploading chunk 47/73...
# Uploading chunk 48/73...
# Uploading chunk 49/73...
# Uploading chunk 50/73...
# Uploading chunk 51/73...
# Uploading chunk 52/73...
# Uploading chunk 53/73...
# Uploading chunk 54/73...
# Uploading chunk 55/73...
# Uploading chunk 56/73...
# Uploading chunk 57/73...
# Uploading chunk 58/73...
# Uploading chunk 59/73...
# Uploading chunk 60/73...
# Uploading chunk 61/73...
# Uploading chunk 62/73...
# Uploading chunk 63/73...
# Uploading chunk 64/73...
# Uploading chunk 65/73...
# Uploading chunk 66/73...
# Uploading chunk 67/73...
# Uploading chunk 68/73...
# Uploading chunk 69/73...
# Uploading chunk 70/73...
# Uploading chunk 71/73...
# Uploading chunk 72/73...
# Uploading chunk 73/73...
# Upload complete.
